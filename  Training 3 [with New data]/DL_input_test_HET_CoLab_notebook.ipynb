# %% [markdown]
# <a href="https://colab.research.google.com/github/Akmazad/deepBrain/blob/master/%20Training%203%20%5Bwith%20New%20data%5D/DL_input_test_HET_CoLab_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import argparse
import torch
import torch.nn as nn
import math
import torch.nn.functional as F
import torch.optim as optim
import numpy as np
import torch
import torch.nn as nn
import torch.utils.data as tdata
import torch.nn.functional as tfunc
import torch.optim as topti
import logging
import os
import torch.cuda
from sklearn.metrics import roc_auc_score
import torch.tensor

class config():
  def __init__(self):
    self.name = "deepbrainStaticConvnet"
    self.DataDir = "gdrive/My Drive/chr1_HET/"

    self.TrainingDataFile = "temp_HET_trainingData_chr1_value.npy"
    self.TrainingLabelFile = "temp_HET_trainingData_chr1_label_all.npy"
    self.TestingDataFile = "temp_HET_validationData_chr1_value.npy"
    self.TestingLabelFile = "temp_HET_validationData_chr1_label_all.npy"

#     self.TrainingDataFile = "HumanFC_ENCODE_EpiMap_nonZero.bin.Seq_Labels_trainingData_chr1_value.npy"
#     self.TrainingLabelFile = "HumanFC_ENCODE_EpiMap_nonZero.bin.Seq_Labels_trainingData_chr1_label_all.npy"
#     self.TestingDataFile = "HumanFC_ENCODE_EpiMap_nonZero.bin.Seq_Labels_validationData_chr1_value.npy"
#     self.TestingLabelFile = "HumanFC_ENCODE_EpiMap_nonZero.bin.Seq_Labels_validationData_chr1_label_all.npy"
    
    self.w_lr = 1e-2
    self.w_lr_min = 8e-7
    self.w_momentum = 0.9
    self.w_weight_decay = 5e-7
    self.w_grad_clip = 5
    self.print_freq = 50
    self.init_channels = 16
    self.layers = 8
    self.BATCH_SIZE = 64
    self.val_batch_size = 256
    self.seed = 0
    self.workers = 4 
    self.alpha_lr = 3e-4
    self.alpha_weight_decay = 1e-4
    self.world_size = -1
    self.rank = 0
    self.dist_url = 'env://'
    self.dist_backend = 'nccl'
    self.gpu = None
    self.multiprocessing_distributed = True
    self.nEpochs = 100
    self.start_epoch = 0

    # architecture-related parameters
    # 3 conv-layers, 1 fully connected layers (See DeepSEA paper)
    self.CONV1_INPUT_CHANNELS = 4
    self.CONV1_OUTPUT_CHANNELS = 320
    self.CONV2_OUTPUT_CHANNELS = 480
    self.CONV3_OUTPUT_CHANNELS = 960
    self.KERNEL_SIZE = 8
    self.POOLING_TH = 4
    self.DROPOUT_l1 = 0.2
    self.DROPOUT_l2 = 0.2
    self.DROPOUT_l3 = 0.5
    self.NUM_OUTPUTS = 566
    self.SEQ_LEN = 1000

    
best_acc1 = 0

# model zone
class BuildModel(nn.Module):
    def __init__(self, args):
        super(BuildModel, self).__init__()

        # Create and initialise weights and biases for the layers.
        # regularization parameters could be introduced later (see deepsea/deepsea_model.py)
        self.conv_layer1 = nn.Conv1d(args.CONV1_INPUT_CHANNELS, args.CONV1_OUTPUT_CHANNELS, args.KERNEL_SIZE)
        self.conv_layer2 = nn.Conv1d(args.CONV1_OUTPUT_CHANNELS, args.CONV2_OUTPUT_CHANNELS, args.KERNEL_SIZE)
        self.conv_layer3 = nn.Conv1d(args.CONV2_OUTPUT_CHANNELS, args.CONV3_OUTPUT_CHANNELS, args.KERNEL_SIZE)

        nChannel = math.floor((args.SEQ_LEN - (args.KERNEL_SIZE - 1)) / args.POOLING_TH)
        nChannel = math.floor((nChannel - (args.KERNEL_SIZE - 1)) / args.POOLING_TH)
        nChannel = math.floor((nChannel - (args.KERNEL_SIZE - 1)) / args.POOLING_TH)
        self.fc1 = nn.Linear(args.CONV3_OUTPUT_CHANNELS * nChannel, args.NUM_OUTPUTS)

    def forward(self, x, args):
        # Create the forward pass through the network.
        x = self.conv_layer1(x)
        x = tfunc.leaky_relu(x, 0.01)
        x = tfunc.max_pool1d(x, args.POOLING_TH)  # downsample by half (i.e. if parameter=4, then by quarter)
        # x = tfunc.batch_norm(x, torch.zeros(args.CONV1_OUTPUT_CHANNELS), torch.ones(args.CONV1_OUTPUT_CHANNELS))
        x = tfunc.dropout(x, args.DROPOUT_l1)

        x = self.conv_layer2(x)
        x = tfunc.leaky_relu(x, 0.01)
        x = tfunc.max_pool1d(x, args.POOLING_TH)
        # x = tfunc.batch_norm(x, torch.zeros(args.CONV2_OUTPUT_CHANNELS), torch.ones(args.CONV2_OUTPUT_CHANNELS))
        x = tfunc.dropout(x, args.DROPOUT_l2)

        x = self.conv_layer3(x)
        x = tfunc.leaky_relu(x, 0.1)
        x = tfunc.max_pool1d(x, args.POOLING_TH)
        # x = tfunc.batch_norm(x, torch.zeros(args.CONV3_OUTPUT_CHANNELS), torch.ones(args.CONV3_OUTPUT_CHANNELS))
        x = tfunc.dropout(x, args.DROPOUT_l3)

        # for the fully connected layer
        x = x.view(x.shape[0], -1)  # Flatten tensor.
        x = self.fc1(x)
        x = tfunc.leaky_relu(x, 0.01)
        #         x = tfunc.dropout(x, 0.2)
        # x = tfunc.batch_norm(x, torch.zeros(K).cuda(), torch.ones(K).cuda())
        x = torch.sigmoid(x)
        # x = F.log_softmax(x)

        return x

class DeepSEA(nn.Module):
    def __init__(self, sequence_length, n_genomic_features):
        """
        Parameters
        ----------
        sequence_length : int
        n_genomic_features : int
        """
        super(DeepSEA, self).__init__()
        conv_kernel_size = 8
        pool_kernel_size = 4

        self.conv_net = nn.Sequential(
            nn.Conv1d(4, 320, kernel_size=conv_kernel_size),
            # nn.ReLU(inplace=True),
            nn.Threshold(0, 1e-06),

            nn.MaxPool1d(
                kernel_size=pool_kernel_size, stride=pool_kernel_size),
            nn.Dropout(p=0.2),

            nn.Conv1d(320, 480, kernel_size=conv_kernel_size),
            # nn.ReLU(inplace=True),
            nn.Threshold(0, 1e-06),
            nn.MaxPool1d(
                kernel_size=pool_kernel_size, stride=pool_kernel_size),
            nn.Dropout(p=0.2),

            nn.Conv1d(480, 960, kernel_size=conv_kernel_size),
            # nn.ReLU(inplace=True),
            nn.Threshold(0, 1e-06),
            nn.Dropout(p=0.5))

        reduce_by = conv_kernel_size - 1
        pool_kernel_size = float(pool_kernel_size)
        self.n_channels = int(
            np.floor(
                (np.floor(
                    (sequence_length - reduce_by) / pool_kernel_size)
                 - reduce_by) / pool_kernel_size)
            - reduce_by)
        self.classifier = nn.Sequential(
            nn.Linear(960 * self.n_channels, n_genomic_features),
            # nn.ReLU(inplace=True),
            nn.Threshold(0, 1e-06),
            nn.Linear(n_genomic_features, n_genomic_features),
            nn.Sigmoid())

    def forward(self, x):
        """Forward propagation of a batch.
        """
        out = self.conv_net(x)
        reshape_out = out.view(out.size(0), 960 * self.n_channels)
        predict = self.classifier(reshape_out)
        return predict


class DeeperDeepSEA(nn.Module):
    """
    A deeper DeepSEA model architecture.
    Parameters
    ----------
    sequence_length : int
        The length of the sequences on which the model trains and and makes
        predictions.
    n_targets : int
        The number of targets (classes) to predict.
    Attributes
    ----------
    conv_net : torch.nn.Sequential
        The convolutional neural network component of the model.
    classifier : torch.nn.Sequential
        The linear classifier and sigmoid transformation components of the
        model.
    """

    def __init__(self, sequence_length, n_targets):
        super(DeeperDeepSEA, self).__init__()
        conv_kernel_size = 8
        pool_kernel_size = 4

        self.conv_net = nn.Sequential(
            nn.Conv1d(4, 320, kernel_size=conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.Conv1d(320, 320, kernel_size=conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(
                kernel_size=pool_kernel_size, stride=pool_kernel_size),
            nn.BatchNorm1d(320),

            nn.Conv1d(320, 480, kernel_size=conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.Conv1d(480, 480, kernel_size=conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.MaxPool1d(
                kernel_size=pool_kernel_size, stride=pool_kernel_size),
            nn.BatchNorm1d(480),
            nn.Dropout(p=0.2),

            nn.Conv1d(480, 960, kernel_size=conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.Conv1d(960, 960, kernel_size=conv_kernel_size),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(960),
            nn.Dropout(p=0.2))

        reduce_by = 2 * (conv_kernel_size - 1)
        pool_kernel_size = float(pool_kernel_size)
        self._n_channels = int(
            np.floor(
                (np.floor(
                    (sequence_length - reduce_by) / pool_kernel_size)
                 - reduce_by) / pool_kernel_size)
            - reduce_by)
        self.classifier = nn.Sequential(
            nn.Linear(960 * self._n_channels, n_targets),
            nn.ReLU(inplace=True),
            nn.BatchNorm1d(n_targets),
            nn.Linear(n_targets, n_targets),
            nn.Sigmoid())

    def forward(self, x):
        """
        Forward propagation of a batch.
        """
        out = self.conv_net(x)
        reshape_out = out.view(out.size(0), 960 * self._n_channels)
        predict = self.classifier(reshape_out)
        return predict

class ReCodeAlphabet(nn.Module):
    def __init__(self):
        super(ReCodeAlphabet, self).__init__()
        #
    def forward(self, input):
        # Swap ACGT to AGCT
        # array has shape (N, 4, 1, 1000)
        # pytorch doesn't support full indexing at the moment, at some point this should work: [:,:,torch.LongTensor([0,2,1,3])]
        input_reordered = [input[:,i,...] for i in [0,2,1,3]]
        input = torch.stack(input_reordered, dim=1)
        # slightly faster but ugly:
        #input = edit_tensor_in_numpy(input, lambda x: x[:,[0,2,1,3], ...])
        return input


class LambdaBase(nn.Sequential):
    def __init__(self, fn, *args):
        super(LambdaBase, self).__init__(*args)
        self.lambda_func = fn
        #
    def forward_prepare(self, input):
        output = []
        for module in self._modules.values():
            output.append(module(input))
        return output if output else input


class Lambda(LambdaBase):
    def forward(self, input):
        return self.lambda_func(self.forward_prepare(input))


def get_model(load_weights = True):
    deepsea_cpu = nn.Sequential( # Sequential,
        nn.Conv2d(4,320,(1, 8),(1, 1)),
        nn.Threshold(0, 1e-06),
        nn.MaxPool2d((1, 4),(1, 4)),
        nn.Dropout(0.2),
        nn.Conv2d(320,480,(1, 8),(1, 1)),
        nn.Threshold(0, 1e-06),
        nn.MaxPool2d((1, 4),(1, 4)),
        nn.Dropout(0.2),
        nn.Conv2d(480,960,(1, 8),(1, 1)),
        nn.Threshold(0, 1e-06),
        nn.Dropout(0.5),
        Lambda(lambda x: x.view(x.size(0),-1)), # Reshape,
        nn.Sequential(Lambda(lambda x: x.view(1,-1) if 1==len(x.size()) else x ),nn.Linear(50880,925)), # Linear,
        nn.Threshold(0, 1e-06),
        nn.Sequential(Lambda(lambda x: x.view(1,-1) if 1==len(x.size()) else x ),nn.Linear(925,919)), # Linear,
        nn.Sigmoid(),
    )
    if load_weights:
        deepsea_cpu.load_state_dict(torch.load('model_files/deepsea_cpu.pth'))
    return nn.Sequential(ReCodeAlphabet(), deepsea_cpu)


class LoadDataset(tdata.Dataset):
    def __init__(self, args, dataPath, dataFile, labelFile):
        # Load data from files.
        # self.inputs = np.memmap(dataPath + dataFile, mode="r").reshape(-1, args.CONV1_INPUT_CHANNELS, args.SEQ_LEN)
        # self.labels = np.memmap(dataPath + labelFile, mode="r").reshape(-1, args.NUM_OUTPUTS)

        self.inputs = np.load(dataPath + dataFile)
        self.labels = np.load(dataPath + labelFile)

        self.length = len(self.labels)

    def __getitem__(self, index):
        # Return a single input/label pair from the dataset.
        inputSample = np.array(self.inputs[index], dtype=np.float32)
        labelSample = np.array(self.labels[index], dtype=np.float32)
        sample = (inputSample, labelSample)
        return sample

    def __len__(self):
        return self.length




def getCustomAccuracy(predicted, target, args):
    # predicted = torch.round(torch.sigmoid(predicted))
    # predicted = torch.round(predicted)
    n_digits = 3
    _predicted = torch.round(predicted * 10 ** n_digits) / (10 ** n_digits)
    __predicted = torch.round(_predicted)

    N = predicted.size(0) * args.NUM_OUTPUTS

    truePred = torch.sum(torch.eq(__predicted, target)).item()
    acc_val = truePred / N

    # print(torch.sum(torch.eq(target, torch.ones(target.shape))).item())
    # print(torch.sum(torch.eq(predicted, torch.ones(target.shape))).item())
    return acc_val


def getCustomAccuracy2(predicted, target, args):
    # predicted = torch.round(torch.sigmoid(predicted))
    # predicted = torch.round(predicted)
    n_digits = 3    # to have something like 0.499 = 0.5
    _predicted = torch.round(predicted * 10 ** n_digits) / (10 ** n_digits)
    __predicted = torch.round(_predicted)



    N = predicted.size(0)
    custom_accuracy = np.zeros(args.NUM_OUTPUTS, dtype=np.float)
    for i in range(args.NUM_OUTPUTS):
        truePred = torch.sum(torch.eq(__predicted[:, i], target[:, i])).item()
        custom_accuracy[i] = truePred/N

    return np.median(custom_accuracy[:288]), np.median(custom_accuracy[288:438]), np.median(custom_accuracy[438:])


def getCustomAccuracy3(predicted, target, args):
    preds = []
    targets = []
    for i in range(10):
        o = F.log_softmax(torch.autograd.Variable(predicted), dim=1)
        t = torch.autograd.Variable(target)

        _, pred = torch.max(o, dim=1)
        preds.append(pred.data)
        targets.append(t.data)

    preds = torch.cat(preds)
    targets = torch.cat(targets)


def getAUCscore(predicted, target, args, logger):
    # n_digits = 3
    # _predicted = torch.round(predicted * 10**n_digits) / (10**n_digits)
    # __predicted = torch.round(_predicted)

    # _predicted = torch.round(predicted).detach()
    __predicted = predicted.detach()
    _target = target.detach()

    aucs = np.zeros(args.NUM_OUTPUTS, dtype=np.float)
    for i in range(args.NUM_OUTPUTS):
        try:
            auc = roc_auc_score(_target.cpu().numpy()[:, i], __predicted.cpu().numpy()[:, i], average='weighted')
            aucs[i] = auc
        except ValueError as e:
            pass
            # logger.info("NA (No positive (i.e. signal) in Test region)")

    # print('Medican AUCs: Accetylation marks: %.3f, RNA-seq: %.3f, TFs: %.3f' % (np.median(aucs[:2]), np.median(aucs[2]), np.median(aucs[3:])))

    return np.median(aucs[:288]), np.median(aucs[288:438]), np.median(aucs[438:])


def get_logger(file_path):
    """ Make python logger """
    # [!] Since tensorboardX use default logger (e.g. logging.info()), we should use custom logger
    logger = logging.getLogger('db2')
    log_format = '%(asctime)s | %(message)s'
    formatter = logging.Formatter(log_format, datefmt='%m/%d %I:%M:%S %p')
    file_handler = logging.FileHandler(file_path)
    file_handler.setFormatter(formatter)
    stream_handler = logging.StreamHandler()
    stream_handler.setFormatter(formatter)

    logger.addHandler(file_handler)
    logger.addHandler(stream_handler)
    logger.setLevel(logging.INFO)

    return logger


def find_perc_uncertainty(output, low, high):
    output = output.detach().cpu().numpy()
    return np.sum(np.logical_and(output>=low, output<=high))/output.size    # returns the proportion of tensor elements are within the range


def train(train_loader, model, criterion, optimizer, epoch, args, logger, device):

    # switch to train mode
    model.train()
    # perc_uncertainty = 0.0

    for i, (input, target) in enumerate(train_loader):
      
        input = input.cuda(device, non_blocking=True)
        target = target.cuda(device, non_blocking=True)
        
        # compute output
        # output = model(input, args)
        output = model(input)
        loss = criterion(output, target.squeeze(1))

        # measure accuracy and record loss
        # acc = getCustomAccuracy(output, target, args)
        perc_uncertainty = find_perc_uncertainty(output, 0.4, 0.6)
        custom_accuracy = getCustomAccuracy2(output, target, args)
        # tAccuracy = getCustomAccuracy3(output, target, args)
        aucs = getAUCscore(output, target, args, logger)

        # compute gradient
        optimizer.zero_grad()

        # add l1 Sparsity
        l1 = 0
        for p in model.parameters():
            l1 = l1 + p.abs().sum()
        loss = loss + 1e-8 * l1

        # do SGD step
        loss.backward()
        optimizer.step()

        if i % args.print_freq == 0 or i == len(train_loader) - 1:
          logger.info("TRAINING: Epoch: %d, Batch: %d/%d, Loss: %.3f, perc_uncertainty: %.3f, custom[HumanFC:%.3f, EpiMap:%.3f, TFs:%.3f], roc[HumanFC:%.3f, EpiMap:%.3f, TFs:%.3f]" 
                      % (epoch + 1, i, len(train_loader) - 1,
                         loss, perc_uncertainty, custom_accuracy[0], 
                         custom_accuracy[1], custom_accuracy[2], 
                         aucs[0], aucs[1], aucs[2]))



def validate(val_loader, model, criterion, args, logger, device):

    # switch to evaluate mode
    model.eval()
    total_ACC, total_RNA, total_TFs = 0, 0, 0
    perc_uncertainty = 0.0

    # losses = []

    with torch.no_grad():
        for i, (input, target) in enumerate(val_loader):
            
            input = input.cuda(device, non_blocking=True)
            target = target.cuda(device, non_blocking=True)
        
            output = model(input)
            loss = criterion(output, target)
            # losses[i] = loss

            # measure accuracy and record loss
            # acc = getCustomAccuracy(output, target, args)
            p = find_perc_uncertainty(output, 0.4, 0.6)
            custom_accuracy = getCustomAccuracy2(output, target, args)
            aucs = getAUCscore(output, target, args, logger)

            total_ACC += np.median(aucs[0])
            total_RNA += np.median(aucs[1])
            total_TFs += np.median(aucs[2])

            if i % args.print_freq == 0 or i == len(val_loader) - 1:
                # progress._print(i)
                # logger.info("batch: %d, loss: %.3f; valid accuracy: custom_accuracy_metric: %.3f, ACC marks: %.3f, RNA-seq: %.3f, TFs: %.3f" % (i+1, loss, acc, aucs[0], aucs[1], aucs[2]))
                logger.info("VALIDATION: Batch: %d/%d, Loss: %.3f, perc_uncertainty: %.3f, custom[HumanFC:%.3f, EpiMap:%.3f, TFs:%.3f], roc[HumanFC: %.3f, EpiMap: %.3f, TFs:%.3f]" % (i, len(val_loader)-1, loss, perc_uncertainty, custom_accuracy[0], custom_accuracy[1], custom_accuracy[2], aucs[0], aucs[1], aucs[2]))
            perc_uncertainty += p

        # logger.info(' * Acc@1 {top1.avg:.3f}'.format(top1=acc))
        logger.info("percentage of uncertainty in validation prediction: {}".format(perc_uncertainty / len(val_loader)))

    total_ACC /= len(val_loader)
    total_RNA /= len(val_loader)
    total_TFs /= len(val_loader)

    return np.median([total_ACC, total_RNA, total_TFs])
    # return np.median(losses), np.median([total_ACC, total_RNA, total_TFs])


def adjust_learning_rate(optimizer, epoch, args, lr_scheduler):
    """Sets the learning rate to the initial LR decayed by 10 every 30 epochs"""
    # lr = args.w_lr * (0.1 ** (epoch // 30))   # option 1
    lr_scheduler.step()     # option 2
    lr = lr_scheduler.get_lr()[0]

    for param_group in optimizer.param_groups:
        param_group['lr'] = lr


def main():
    # Training settings
    args = config()
    use_cuda = torch.cuda.is_available()
    torch.manual_seed(args.seed)
    device = torch.device("cuda" if use_cuda else "cpu")
    print(device)

    DataPath = args.DataDir
    logger = get_logger(os.path.join(os.path.join(DataPath, args.name, 'staticConvNet'), "{}.log".format(args.name)))

    trainDataset = LoadDataset(args, dataPath=DataPath, dataFile=args.TrainingDataFile,
                               labelFile=args.TrainingLabelFile)
    # define sampler
    train_sampler = torch.utils.data.sampler.RandomSampler(trainDataset)

    trainLoader = tdata.DataLoader(trainDataset, batch_size=args.BATCH_SIZE, shuffle=(train_sampler is None),
                                   num_workers=args.workers, pin_memory=True, sampler=train_sampler)

    # Load the testing dataset, and create a data loader to generate a batch. CHANGE THIS ONCE TESTING DATASET IS READY
    valDataset = LoadDataset(args, dataPath=DataPath, dataFile=args.TestingDataFile, labelFile=args.TestingLabelFile)
    valLoader = tdata.DataLoader(dataset=valDataset, batch_size=args.val_batch_size, shuffle=False,
                                 num_workers=args.workers, pin_memory=True)

    # build the model and criterion
    # model = BuildModel(args).to(device)
    # model = DeepSEA(args.SEQ_LEN, args.NUM_OUTPUTS).to(device)
    model = DeeperDeepSEA(args.SEQ_LEN, args.NUM_OUTPUTS).to(device)
    # model = get_model(load_weights=False)

    # Add a sigmoid activation function to the output.  Use a binary cross entropy
    criterion = nn.BCELoss().to(device)
    # criterion = nn.CrossEntropyLoss()

    # optimiser = topti.Adam(model.parameters(), lr=args.w_lr)  # Minimise the loss using the Adam algorithm.
#     optimiser = torch.optim.Adam(model.parameters(), args.w_lr, betas=(0.5, 0.999),
#                                    weight_decay=args.w_weight_decay)
    # print(model.parameters())
    optimiser = torch.optim.SGD(model.parameters(), args.w_lr, momentum=args.w_momentum, weight_decay=args.w_weight_decay)

    # model = DeepSEA(args.SEQ_LEN, args.NUM_OUTPUTS).to(device)
    # criterion = nn.BCELoss()
    # optimiser = (torch.optim.SGD, {"lr": args.w_lr, "weight_decay": 1e-6, "momentum": 0.9})



    lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimiser, args.nEpochs, eta_min=args.w_lr_min)
    # lr_scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimiser, args.nEpochs, eta_min=0)
    # scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimiser, 'min')

    best_acc1 = 0.0
    for epoch in range(args.start_epoch, args.nEpochs):

        adjust_learning_rate(optimiser, epoch, args, lr_scheduler)

        # train for one epoch
        train(trainLoader, model, criterion, optimiser, epoch, args, logger, device)

        # evaluate on validation set
        acc1 = validate(valLoader, model, criterion, args, logger, device)

        # scheduler.step(acc1[1])

        # remember best acc@1 and save checkpoint
        is_best = acc1 > best_acc1
        best_acc1 = max(acc1, best_acc1)

    # if (args.save_model):
    #     torch.save(model.state_dict(), "mnist_cnn.pt")
    torch.save(model.state_dict(), "deepBrain2_cnn.pt")


if __name__ == '__main__':
    main()
# Out:
# cuda
# 09/02 09:12:00 AM | TRAINING: Epoch: 1, Batch: 0/32, Loss: 0.709, perc_uncertainty: 0.788, custom[HumanFC:0.500, EpiMap:0.516, TFs:0.500], roc[HumanFC:0.495, EpiMap:0.485, TFs:0.436]
# 09/02 09:12:00 AM | TRAINING: Epoch: 1, Batch: 0/32, Loss: 0.709, perc_uncertainty: 0.788, custom[HumanFC:0.500, EpiMap:0.516, TFs:0.500], roc[HumanFC:0.495, EpiMap:0.485, TFs:0.436]
# 09/02 09:12:00 AM | TRAINING: Epoch: 1, Batch: 0/32, Loss: 0.709, perc_uncertainty: 0.788, custom[HumanFC:0.500, EpiMap:0.516, TFs:0.500], roc[HumanFC:0.495, EpiMap:0.485, TFs:0.436]
# 09/02 09:12:00 AM | TRAINING: Epoch: 1, Batch: 0/32, Loss: 0.709, perc_uncertainty: 0.788, custom[HumanFC:0.500, EpiMap:0.516, TFs:0.500], roc[HumanFC:0.495, EpiMap:0.485, TFs:0.436]
# 09/02 09:12:34 AM | TRAINING: Epoch: 1, Batch: 32/32, Loss: 0.708, perc_uncertainty: 0.785, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.500], roc[HumanFC:0.040, EpiMap:0.431, TFs:0.000]
# 09/02 09:12:34 AM | TRAINING: Epoch: 1, Batch: 32/32, Loss: 0.708, perc_uncertainty: 0.785, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.500], roc[HumanFC:0.040, EpiMap:0.431, TFs:0.000]
# 09/02 09:12:34 AM | TRAINING: Epoch: 1, Batch: 32/32, Loss: 0.708, perc_uncertainty: 0.785, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.500], roc[HumanFC:0.040, EpiMap:0.431, TFs:0.000]
# 09/02 09:12:34 AM | TRAINING: Epoch: 1, Batch: 32/32, Loss: 0.708, perc_uncertainty: 0.785, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.500], roc[HumanFC:0.040, EpiMap:0.431, TFs:0.000]
# 09/02 09:12:36 AM | VALIDATION: Batch: 0/1, Loss: 0.693, perc_uncertainty: 0.000, custom[HumanFC:0.354, EpiMap:0.607, TFs:0.744], roc[HumanFC: 0.504, EpiMap: 0.490, TFs:0.471]
# 09/02 09:12:36 AM | VALIDATION: Batch: 0/1, Loss: 0.693, perc_uncertainty: 0.000, custom[HumanFC:0.354, EpiMap:0.607, TFs:0.744], roc[HumanFC: 0.504, EpiMap: 0.490, TFs:0.471]
# 09/02 09:12:36 AM | VALIDATION: Batch: 0/1, Loss: 0.693, perc_uncertainty: 0.000, custom[HumanFC:0.354, EpiMap:0.607, TFs:0.744], roc[HumanFC: 0.504, EpiMap: 0.490, TFs:0.471]
# 09/02 09:12:36 AM | VALIDATION: Batch: 0/1, Loss: 0.693, perc_uncertainty: 0.000, custom[HumanFC:0.354, EpiMap:0.607, TFs:0.744], roc[HumanFC: 0.504, EpiMap: 0.490, TFs:0.471]
# 09/02 09:12:38 AM | VALIDATION: Batch: 1/1, Loss: 0.693, perc_uncertainty: 0.999, custom[HumanFC:0.366, EpiMap:0.543, TFs:0.716], roc[HumanFC: 0.451, EpiMap: 0.482, TFs:0.476]
# 09/02 09:12:38 AM | VALIDATION: Batch: 1/1, Loss: 0.693, perc_uncertainty: 0.999, custom[HumanFC:0.366, EpiMap:0.543, TFs:0.716], roc[HumanFC: 0.451, EpiMap: 0.482, TFs:0.476]
# 09/02 09:12:38 AM | VALIDATION: Batch: 1/1, Loss: 0.693, perc_uncertainty: 0.999, custom[HumanFC:0.366, EpiMap:0.543, TFs:0.716], roc[HumanFC: 0.451, EpiMap: 0.482, TFs:0.476]
# 09/02 09:12:38 AM | VALIDATION: Batch: 1/1, Loss: 0.693, perc_uncertainty: 0.999, custom[HumanFC:0.366, EpiMap:0.543, TFs:0.716], roc[HumanFC: 0.451, EpiMap: 0.482, TFs:0.476]
# 09/02 09:12:38 AM | percentage of uncertainty in validation prediction: 0.9992030448752478
# 09/02 09:12:38 AM | percentage of uncertainty in validation prediction: 0.9992030448752478
# 09/02 09:12:38 AM | percentage of uncertainty in validation prediction: 0.9992030448752478
# 09/02 09:12:38 AM | percentage of uncertainty in validation prediction: 0.9992030448752478
# 09/02 09:12:39 AM | TRAINING: Epoch: 2, Batch: 0/32, Loss: 0.706, perc_uncertainty: 0.783, custom[HumanFC:0.516, EpiMap:0.516, TFs:0.516], roc[HumanFC:0.541, EpiMap:0.507, TFs:0.521]
# 09/02 09:12:39 AM | TRAINING: Epoch: 2, Batch: 0/32, Loss: 0.706, perc_uncertainty: 0.783, custom[HumanFC:0.516, EpiMap:0.516, TFs:0.516], roc[HumanFC:0.541, EpiMap:0.507, TFs:0.521]
# 09/02 09:12:39 AM | TRAINING: Epoch: 2, Batch: 0/32, Loss: 0.706, perc_uncertainty: 0.783, custom[HumanFC:0.516, EpiMap:0.516, TFs:0.516], roc[HumanFC:0.541, EpiMap:0.507, TFs:0.521]
# 09/02 09:12:39 AM | TRAINING: Epoch: 2, Batch: 0/32, Loss: 0.706, perc_uncertainty: 0.783, custom[HumanFC:0.516, EpiMap:0.516, TFs:0.516], roc[HumanFC:0.541, EpiMap:0.507, TFs:0.521]
# 09/02 09:13:13 AM | TRAINING: Epoch: 2, Batch: 32/32, Loss: 0.704, perc_uncertainty: 0.794, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.500], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.189]
# 09/02 09:13:13 AM | TRAINING: Epoch: 2, Batch: 32/32, Loss: 0.704, perc_uncertainty: 0.794, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.500], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.189]
# 09/02 09:13:13 AM | TRAINING: Epoch: 2, Batch: 32/32, Loss: 0.704, perc_uncertainty: 0.794, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.500], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.189]
# 09/02 09:13:13 AM | TRAINING: Epoch: 2, Batch: 32/32, Loss: 0.704, perc_uncertainty: 0.794, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.500], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.189]
# 09/02 09:13:16 AM | VALIDATION: Batch: 0/1, Loss: 0.696, perc_uncertainty: 0.000, custom[HumanFC:0.506, EpiMap:0.555, TFs:0.502], roc[HumanFC: 0.503, EpiMap: 0.490, TFs:0.461]
# 09/02 09:13:16 AM | VALIDATION: Batch: 0/1, Loss: 0.696, perc_uncertainty: 0.000, custom[HumanFC:0.506, EpiMap:0.555, TFs:0.502], roc[HumanFC: 0.503, EpiMap: 0.490, TFs:0.461]
# 09/02 09:13:16 AM | VALIDATION: Batch: 0/1, Loss: 0.696, perc_uncertainty: 0.000, custom[HumanFC:0.506, EpiMap:0.555, TFs:0.502], roc[HumanFC: 0.503, EpiMap: 0.490, TFs:0.461]
# 09/02 09:13:16 AM | VALIDATION: Batch: 0/1, Loss: 0.696, perc_uncertainty: 0.000, custom[HumanFC:0.506, EpiMap:0.555, TFs:0.502], roc[HumanFC: 0.503, EpiMap: 0.490, TFs:0.461]
# 09/02 09:13:17 AM | VALIDATION: Batch: 1/1, Loss: 0.696, perc_uncertainty: 0.943, custom[HumanFC:0.512, EpiMap:0.561, TFs:0.497], roc[HumanFC: 0.455, EpiMap: 0.495, TFs:0.462]
# 09/02 09:13:17 AM | VALIDATION: Batch: 1/1, Loss: 0.696, perc_uncertainty: 0.943, custom[HumanFC:0.512, EpiMap:0.561, TFs:0.497], roc[HumanFC: 0.455, EpiMap: 0.495, TFs:0.462]
# 09/02 09:13:17 AM | VALIDATION: Batch: 1/1, Loss: 0.696, perc_uncertainty: 0.943, custom[HumanFC:0.512, EpiMap:0.561, TFs:0.497], roc[HumanFC: 0.455, EpiMap: 0.495, TFs:0.462]
# 09/02 09:13:17 AM | VALIDATION: Batch: 1/1, Loss: 0.696, perc_uncertainty: 0.943, custom[HumanFC:0.512, EpiMap:0.561, TFs:0.497], roc[HumanFC: 0.455, EpiMap: 0.495, TFs:0.462]
# 09/02 09:13:17 AM | percentage of uncertainty in validation prediction: 0.9421829214427304
# 09/02 09:13:17 AM | percentage of uncertainty in validation prediction: 0.9421829214427304
# 09/02 09:13:17 AM | percentage of uncertainty in validation prediction: 0.9421829214427304
# 09/02 09:13:17 AM | percentage of uncertainty in validation prediction: 0.9421829214427304
# 09/02 09:13:19 AM | TRAINING: Epoch: 3, Batch: 0/32, Loss: 0.703, perc_uncertainty: 0.789, custom[HumanFC:0.516, EpiMap:0.523, TFs:0.516], roc[HumanFC:0.000, EpiMap:0.547, TFs:0.533]
# 09/02 09:13:19 AM | TRAINING: Epoch: 3, Batch: 0/32, Loss: 0.703, perc_uncertainty: 0.789, custom[HumanFC:0.516, EpiMap:0.523, TFs:0.516], roc[HumanFC:0.000, EpiMap:0.547, TFs:0.533]
# 09/02 09:13:19 AM | TRAINING: Epoch: 3, Batch: 0/32, Loss: 0.703, perc_uncertainty: 0.789, custom[HumanFC:0.516, EpiMap:0.523, TFs:0.516], roc[HumanFC:0.000, EpiMap:0.547, TFs:0.533]
# 09/02 09:13:19 AM | TRAINING: Epoch: 3, Batch: 0/32, Loss: 0.703, perc_uncertainty: 0.789, custom[HumanFC:0.516, EpiMap:0.523, TFs:0.516], roc[HumanFC:0.000, EpiMap:0.547, TFs:0.533]
# 09/02 09:13:53 AM | TRAINING: Epoch: 3, Batch: 32/32, Loss: 0.701, perc_uncertainty: 0.802, custom[HumanFC:0.500, EpiMap:0.525, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.579, TFs:0.474]
# 09/02 09:13:53 AM | TRAINING: Epoch: 3, Batch: 32/32, Loss: 0.701, perc_uncertainty: 0.802, custom[HumanFC:0.500, EpiMap:0.525, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.579, TFs:0.474]
# 09/02 09:13:53 AM | TRAINING: Epoch: 3, Batch: 32/32, Loss: 0.701, perc_uncertainty: 0.802, custom[HumanFC:0.500, EpiMap:0.525, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.579, TFs:0.474]
# 09/02 09:13:53 AM | TRAINING: Epoch: 3, Batch: 32/32, Loss: 0.701, perc_uncertainty: 0.802, custom[HumanFC:0.500, EpiMap:0.525, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.579, TFs:0.474]
# 09/02 09:13:56 AM | VALIDATION: Batch: 0/1, Loss: 0.699, perc_uncertainty: 0.000, custom[HumanFC:0.512, EpiMap:0.531, TFs:0.488], roc[HumanFC: 0.496, EpiMap: 0.491, TFs:0.452]
# 09/02 09:13:56 AM | VALIDATION: Batch: 0/1, Loss: 0.699, perc_uncertainty: 0.000, custom[HumanFC:0.512, EpiMap:0.531, TFs:0.488], roc[HumanFC: 0.496, EpiMap: 0.491, TFs:0.452]
# 09/02 09:13:56 AM | VALIDATION: Batch: 0/1, Loss: 0.699, perc_uncertainty: 0.000, custom[HumanFC:0.512, EpiMap:0.531, TFs:0.488], roc[HumanFC: 0.496, EpiMap: 0.491, TFs:0.452]
# 09/02 09:13:56 AM | VALIDATION: Batch: 0/1, Loss: 0.699, perc_uncertainty: 0.000, custom[HumanFC:0.512, EpiMap:0.531, TFs:0.488], roc[HumanFC: 0.496, EpiMap: 0.491, TFs:0.452]
# 09/02 09:13:57 AM | VALIDATION: Batch: 1/1, Loss: 0.699, perc_uncertainty: 0.884, custom[HumanFC:0.500, EpiMap:0.549, TFs:0.473], roc[HumanFC: 0.465, EpiMap: 0.494, TFs:0.453]
# 09/02 09:13:57 AM | VALIDATION: Batch: 1/1, Loss: 0.699, perc_uncertainty: 0.884, custom[HumanFC:0.500, EpiMap:0.549, TFs:0.473], roc[HumanFC: 0.465, EpiMap: 0.494, TFs:0.453]
# 09/02 09:13:57 AM | VALIDATION: Batch: 1/1, Loss: 0.699, perc_uncertainty: 0.884, custom[HumanFC:0.500, EpiMap:0.549, TFs:0.473], roc[HumanFC: 0.465, EpiMap: 0.494, TFs:0.453]
# 09/02 09:13:57 AM | VALIDATION: Batch: 1/1, Loss: 0.699, perc_uncertainty: 0.884, custom[HumanFC:0.500, EpiMap:0.549, TFs:0.473], roc[HumanFC: 0.465, EpiMap: 0.494, TFs:0.453]
# 09/02 09:13:57 AM | percentage of uncertainty in validation prediction: 0.88275173311859
# 09/02 09:13:57 AM | percentage of uncertainty in validation prediction: 0.88275173311859
# 09/02 09:13:57 AM | percentage of uncertainty in validation prediction: 0.88275173311859
# 09/02 09:13:57 AM | percentage of uncertainty in validation prediction: 0.88275173311859
# 09/02 09:13:59 AM | TRAINING: Epoch: 4, Batch: 0/32, Loss: 0.699, perc_uncertainty: 0.794, custom[HumanFC:0.516, EpiMap:0.531, TFs:0.531], roc[HumanFC:0.352, EpiMap:0.558, TFs:0.577]
# 09/02 09:13:59 AM | TRAINING: Epoch: 4, Batch: 0/32, Loss: 0.699, perc_uncertainty: 0.794, custom[HumanFC:0.516, EpiMap:0.531, TFs:0.531], roc[HumanFC:0.352, EpiMap:0.558, TFs:0.577]
# 09/02 09:13:59 AM | TRAINING: Epoch: 4, Batch: 0/32, Loss: 0.699, perc_uncertainty: 0.794, custom[HumanFC:0.516, EpiMap:0.531, TFs:0.531], roc[HumanFC:0.352, EpiMap:0.558, TFs:0.577]
# 09/02 09:13:59 AM | TRAINING: Epoch: 4, Batch: 0/32, Loss: 0.699, perc_uncertainty: 0.794, custom[HumanFC:0.516, EpiMap:0.531, TFs:0.531], roc[HumanFC:0.352, EpiMap:0.558, TFs:0.577]
# 09/02 09:14:33 AM | TRAINING: Epoch: 4, Batch: 32/32, Loss: 0.698, perc_uncertainty: 0.797, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.426]
# 09/02 09:14:33 AM | TRAINING: Epoch: 4, Batch: 32/32, Loss: 0.698, perc_uncertainty: 0.797, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.426]
# 09/02 09:14:33 AM | TRAINING: Epoch: 4, Batch: 32/32, Loss: 0.698, perc_uncertainty: 0.797, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.426]
# 09/02 09:14:33 AM | TRAINING: Epoch: 4, Batch: 32/32, Loss: 0.698, perc_uncertainty: 0.797, custom[HumanFC:0.500, EpiMap:0.500, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.426]
# 09/02 09:14:36 AM | VALIDATION: Batch: 0/1, Loss: 0.697, perc_uncertainty: 0.000, custom[HumanFC:0.523, EpiMap:0.533, TFs:0.488], roc[HumanFC: 0.507, EpiMap: 0.486, TFs:0.466]
# 09/02 09:14:36 AM | VALIDATION: Batch: 0/1, Loss: 0.697, perc_uncertainty: 0.000, custom[HumanFC:0.523, EpiMap:0.533, TFs:0.488], roc[HumanFC: 0.507, EpiMap: 0.486, TFs:0.466]
# 09/02 09:14:36 AM | VALIDATION: Batch: 0/1, Loss: 0.697, perc_uncertainty: 0.000, custom[HumanFC:0.523, EpiMap:0.533, TFs:0.488], roc[HumanFC: 0.507, EpiMap: 0.486, TFs:0.466]
# 09/02 09:14:36 AM | VALIDATION: Batch: 0/1, Loss: 0.697, perc_uncertainty: 0.000, custom[HumanFC:0.523, EpiMap:0.533, TFs:0.488], roc[HumanFC: 0.507, EpiMap: 0.486, TFs:0.466]
# 09/02 09:14:37 AM | VALIDATION: Batch: 1/1, Loss: 0.697, perc_uncertainty: 0.885, custom[HumanFC:0.512, EpiMap:0.555, TFs:0.476], roc[HumanFC: 0.464, EpiMap: 0.496, TFs:0.453]
# 09/02 09:14:37 AM | VALIDATION: Batch: 1/1, Loss: 0.697, perc_uncertainty: 0.885, custom[HumanFC:0.512, EpiMap:0.555, TFs:0.476], roc[HumanFC: 0.464, EpiMap: 0.496, TFs:0.453]
# 09/02 09:14:37 AM | VALIDATION: Batch: 1/1, Loss: 0.697, perc_uncertainty: 0.885, custom[HumanFC:0.512, EpiMap:0.555, TFs:0.476], roc[HumanFC: 0.464, EpiMap: 0.496, TFs:0.453]
# 09/02 09:14:37 AM | VALIDATION: Batch: 1/1, Loss: 0.697, perc_uncertainty: 0.885, custom[HumanFC:0.512, EpiMap:0.555, TFs:0.476], roc[HumanFC: 0.464, EpiMap: 0.496, TFs:0.453]
# 09/02 09:14:37 AM | percentage of uncertainty in validation prediction: 0.8821951522504956
# 09/02 09:14:37 AM | percentage of uncertainty in validation prediction: 0.8821951522504956
# 09/02 09:14:37 AM | percentage of uncertainty in validation prediction: 0.8821951522504956
# 09/02 09:14:37 AM | percentage of uncertainty in validation prediction: 0.8821951522504956
# 09/02 09:14:38 AM | TRAINING: Epoch: 5, Batch: 0/32, Loss: 0.692, perc_uncertainty: 0.798, custom[HumanFC:0.516, EpiMap:0.562, TFs:0.547], roc[HumanFC:0.566, EpiMap:0.616, TFs:0.593]
# 09/02 09:14:38 AM | TRAINING: Epoch: 5, Batch: 0/32, Loss: 0.692, perc_uncertainty: 0.798, custom[HumanFC:0.516, EpiMap:0.562, TFs:0.547], roc[HumanFC:0.566, EpiMap:0.616, TFs:0.593]
# 09/02 09:14:38 AM | TRAINING: Epoch: 5, Batch: 0/32, Loss: 0.692, perc_uncertainty: 0.798, custom[HumanFC:0.516, EpiMap:0.562, TFs:0.547], roc[HumanFC:0.566, EpiMap:0.616, TFs:0.593]
# 09/02 09:14:38 AM | TRAINING: Epoch: 5, Batch: 0/32, Loss: 0.692, perc_uncertainty: 0.798, custom[HumanFC:0.516, EpiMap:0.562, TFs:0.547], roc[HumanFC:0.566, EpiMap:0.616, TFs:0.593]
# 09/02 09:15:13 AM | TRAINING: Epoch: 5, Batch: 32/32, Loss: 0.693, perc_uncertainty: 0.797, custom[HumanFC:0.525, EpiMap:0.550, TFs:0.500], roc[HumanFC:0.000, EpiMap:0.639, TFs:0.000]
# 09/02 09:15:13 AM | TRAINING: Epoch: 5, Batch: 32/32, Loss: 0.693, perc_uncertainty: 0.797, custom[HumanFC:0.525, EpiMap:0.550, TFs:0.500], roc[HumanFC:0.000, EpiMap:0.639, TFs:0.000]
# 09/02 09:15:13 AM | TRAINING: Epoch: 5, Batch: 32/32, Loss: 0.693, perc_uncertainty: 0.797, custom[HumanFC:0.525, EpiMap:0.550, TFs:0.500], roc[HumanFC:0.000, EpiMap:0.639, TFs:0.000]
# 09/02 09:15:13 AM | TRAINING: Epoch: 5, Batch: 32/32, Loss: 0.693, perc_uncertainty: 0.797, custom[HumanFC:0.525, EpiMap:0.550, TFs:0.500], roc[HumanFC:0.000, EpiMap:0.639, TFs:0.000]
# 09/02 09:15:15 AM | VALIDATION: Batch: 0/1, Loss: 0.694, perc_uncertainty: 0.000, custom[HumanFC:0.527, EpiMap:0.557, TFs:0.488], roc[HumanFC: 0.507, EpiMap: 0.492, TFs:0.459]
# 09/02 09:15:15 AM | VALIDATION: Batch: 0/1, Loss: 0.694, perc_uncertainty: 0.000, custom[HumanFC:0.527, EpiMap:0.557, TFs:0.488], roc[HumanFC: 0.507, EpiMap: 0.492, TFs:0.459]
# 09/02 09:15:15 AM | VALIDATION: Batch: 0/1, Loss: 0.694, perc_uncertainty: 0.000, custom[HumanFC:0.527, EpiMap:0.557, TFs:0.488], roc[HumanFC: 0.507, EpiMap: 0.492, TFs:0.459]
# 09/02 09:15:15 AM | VALIDATION: Batch: 0/1, Loss: 0.694, perc_uncertainty: 0.000, custom[HumanFC:0.527, EpiMap:0.557, TFs:0.488], roc[HumanFC: 0.507, EpiMap: 0.492, TFs:0.459]
# 09/02 09:15:17 AM | VALIDATION: Batch: 1/1, Loss: 0.694, perc_uncertainty: 0.887, custom[HumanFC:0.521, EpiMap:0.573, TFs:0.476], roc[HumanFC: 0.443, EpiMap: 0.505, TFs:0.448]
# 09/02 09:15:17 AM | VALIDATION: Batch: 1/1, Loss: 0.694, perc_uncertainty: 0.887, custom[HumanFC:0.521, EpiMap:0.573, TFs:0.476], roc[HumanFC: 0.443, EpiMap: 0.505, TFs:0.448]
# 09/02 09:15:17 AM | VALIDATION: Batch: 1/1, Loss: 0.694, perc_uncertainty: 0.887, custom[HumanFC:0.521, EpiMap:0.573, TFs:0.476], roc[HumanFC: 0.443, EpiMap: 0.505, TFs:0.448]
# 09/02 09:15:17 AM | VALIDATION: Batch: 1/1, Loss: 0.694, perc_uncertainty: 0.887, custom[HumanFC:0.521, EpiMap:0.573, TFs:0.476], roc[HumanFC: 0.443, EpiMap: 0.505, TFs:0.448]
# 09/02 09:15:17 AM | percentage of uncertainty in validation prediction: 0.8843502724241575
# 09/02 09:15:17 AM | percentage of uncertainty in validation prediction: 0.8843502724241575
# 09/02 09:15:17 AM | percentage of uncertainty in validation prediction: 0.8843502724241575
# 09/02 09:15:17 AM | percentage of uncertainty in validation prediction: 0.8843502724241575
# 09/02 09:15:18 AM | TRAINING: Epoch: 6, Batch: 0/32, Loss: 0.692, perc_uncertainty: 0.802, custom[HumanFC:0.531, EpiMap:0.547, TFs:0.531], roc[HumanFC:0.668, EpiMap:0.601, TFs:0.631]
# 09/02 09:15:18 AM | TRAINING: Epoch: 6, Batch: 0/32, Loss: 0.692, perc_uncertainty: 0.802, custom[HumanFC:0.531, EpiMap:0.547, TFs:0.531], roc[HumanFC:0.668, EpiMap:0.601, TFs:0.631]
# 09/02 09:15:18 AM | TRAINING: Epoch: 6, Batch: 0/32, Loss: 0.692, perc_uncertainty: 0.802, custom[HumanFC:0.531, EpiMap:0.547, TFs:0.531], roc[HumanFC:0.668, EpiMap:0.601, TFs:0.631]
# 09/02 09:15:18 AM | TRAINING: Epoch: 6, Batch: 0/32, Loss: 0.692, perc_uncertainty: 0.802, custom[HumanFC:0.531, EpiMap:0.547, TFs:0.531], roc[HumanFC:0.668, EpiMap:0.601, TFs:0.631]
# 09/02 09:15:53 AM | TRAINING: Epoch: 6, Batch: 32/32, Loss: 0.688, perc_uncertainty: 0.800, custom[HumanFC:0.550, EpiMap:0.550, TFs:0.550], roc[HumanFC:0.421, EpiMap:0.627, TFs:0.653]
# 09/02 09:15:53 AM | TRAINING: Epoch: 6, Batch: 32/32, Loss: 0.688, perc_uncertainty: 0.800, custom[HumanFC:0.550, EpiMap:0.550, TFs:0.550], roc[HumanFC:0.421, EpiMap:0.627, TFs:0.653]
# 09/02 09:15:53 AM | TRAINING: Epoch: 6, Batch: 32/32, Loss: 0.688, perc_uncertainty: 0.800, custom[HumanFC:0.550, EpiMap:0.550, TFs:0.550], roc[HumanFC:0.421, EpiMap:0.627, TFs:0.653]
# 09/02 09:15:53 AM | TRAINING: Epoch: 6, Batch: 32/32, Loss: 0.688, perc_uncertainty: 0.800, custom[HumanFC:0.550, EpiMap:0.550, TFs:0.550], roc[HumanFC:0.421, EpiMap:0.627, TFs:0.653]
# 09/02 09:15:55 AM | VALIDATION: Batch: 0/1, Loss: 0.692, perc_uncertainty: 0.000, custom[HumanFC:0.539, EpiMap:0.570, TFs:0.504], roc[HumanFC: 0.517, EpiMap: 0.486, TFs:0.458]
# 09/02 09:15:55 AM | VALIDATION: Batch: 0/1, Loss: 0.692, perc_uncertainty: 0.000, custom[HumanFC:0.539, EpiMap:0.570, TFs:0.504], roc[HumanFC: 0.517, EpiMap: 0.486, TFs:0.458]
# 09/02 09:15:55 AM | VALIDATION: Batch: 0/1, Loss: 0.692, perc_uncertainty: 0.000, custom[HumanFC:0.539, EpiMap:0.570, TFs:0.504], roc[HumanFC: 0.517, EpiMap: 0.486, TFs:0.458]
# 09/02 09:15:55 AM | VALIDATION: Batch: 0/1, Loss: 0.692, perc_uncertainty: 0.000, custom[HumanFC:0.539, EpiMap:0.570, TFs:0.504], roc[HumanFC: 0.517, EpiMap: 0.486, TFs:0.458]
# 09/02 09:15:57 AM | VALIDATION: Batch: 1/1, Loss: 0.691, perc_uncertainty: 0.891, custom[HumanFC:0.537, EpiMap:0.585, TFs:0.494], roc[HumanFC: 0.456, EpiMap: 0.499, TFs:0.440]
# 09/02 09:15:57 AM | VALIDATION: Batch: 1/1, Loss: 0.691, perc_uncertainty: 0.891, custom[HumanFC:0.537, EpiMap:0.585, TFs:0.494], roc[HumanFC: 0.456, EpiMap: 0.499, TFs:0.440]
# 09/02 09:15:57 AM | VALIDATION: Batch: 1/1, Loss: 0.691, perc_uncertainty: 0.891, custom[HumanFC:0.537, EpiMap:0.585, TFs:0.494], roc[HumanFC: 0.456, EpiMap: 0.499, TFs:0.440]
# 09/02 09:15:57 AM | VALIDATION: Batch: 1/1, Loss: 0.691, perc_uncertainty: 0.891, custom[HumanFC:0.537, EpiMap:0.585, TFs:0.494], roc[HumanFC: 0.456, EpiMap: 0.499, TFs:0.440]
# 09/02 09:15:57 AM | percentage of uncertainty in validation prediction: 0.8877019615077997
# 09/02 09:15:57 AM | percentage of uncertainty in validation prediction: 0.8877019615077997
# 09/02 09:15:57 AM | percentage of uncertainty in validation prediction: 0.8877019615077997
# 09/02 09:15:57 AM | percentage of uncertainty in validation prediction: 0.8877019615077997
# 09/02 09:15:58 AM | TRAINING: Epoch: 7, Batch: 0/32, Loss: 0.687, perc_uncertainty: 0.806, custom[HumanFC:0.531, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.650, EpiMap:0.654, TFs:0.697]
# 09/02 09:15:58 AM | TRAINING: Epoch: 7, Batch: 0/32, Loss: 0.687, perc_uncertainty: 0.806, custom[HumanFC:0.531, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.650, EpiMap:0.654, TFs:0.697]
# 09/02 09:15:58 AM | TRAINING: Epoch: 7, Batch: 0/32, Loss: 0.687, perc_uncertainty: 0.806, custom[HumanFC:0.531, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.650, EpiMap:0.654, TFs:0.697]
# 09/02 09:15:58 AM | TRAINING: Epoch: 7, Batch: 0/32, Loss: 0.687, perc_uncertainty: 0.806, custom[HumanFC:0.531, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.650, EpiMap:0.654, TFs:0.697]
# 09/02 09:16:33 AM | TRAINING: Epoch: 7, Batch: 32/32, Loss: 0.682, perc_uncertainty: 0.800, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.550], roc[HumanFC:0.737, EpiMap:0.709, TFs:0.572]
# 09/02 09:16:33 AM | TRAINING: Epoch: 7, Batch: 32/32, Loss: 0.682, perc_uncertainty: 0.800, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.550], roc[HumanFC:0.737, EpiMap:0.709, TFs:0.572]
# 09/02 09:16:33 AM | TRAINING: Epoch: 7, Batch: 32/32, Loss: 0.682, perc_uncertainty: 0.800, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.550], roc[HumanFC:0.737, EpiMap:0.709, TFs:0.572]
# 09/02 09:16:33 AM | TRAINING: Epoch: 7, Batch: 32/32, Loss: 0.682, perc_uncertainty: 0.800, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.550], roc[HumanFC:0.737, EpiMap:0.709, TFs:0.572]
# 09/02 09:16:35 AM | VALIDATION: Batch: 0/1, Loss: 0.690, perc_uncertainty: 0.000, custom[HumanFC:0.543, EpiMap:0.570, TFs:0.504], roc[HumanFC: 0.507, EpiMap: 0.487, TFs:0.448]
# 09/02 09:16:35 AM | VALIDATION: Batch: 0/1, Loss: 0.690, perc_uncertainty: 0.000, custom[HumanFC:0.543, EpiMap:0.570, TFs:0.504], roc[HumanFC: 0.507, EpiMap: 0.487, TFs:0.448]
# 09/02 09:16:35 AM | VALIDATION: Batch: 0/1, Loss: 0.690, perc_uncertainty: 0.000, custom[HumanFC:0.543, EpiMap:0.570, TFs:0.504], roc[HumanFC: 0.507, EpiMap: 0.487, TFs:0.448]
# 09/02 09:16:35 AM | VALIDATION: Batch: 0/1, Loss: 0.690, perc_uncertainty: 0.000, custom[HumanFC:0.543, EpiMap:0.570, TFs:0.504], roc[HumanFC: 0.507, EpiMap: 0.487, TFs:0.448]
# 09/02 09:16:36 AM | VALIDATION: Batch: 1/1, Loss: 0.689, perc_uncertainty: 0.891, custom[HumanFC:0.555, EpiMap:0.598, TFs:0.482], roc[HumanFC: 0.458, EpiMap: 0.497, TFs:0.435]
# 09/02 09:16:36 AM | VALIDATION: Batch: 1/1, Loss: 0.689, perc_uncertainty: 0.891, custom[HumanFC:0.555, EpiMap:0.598, TFs:0.482], roc[HumanFC: 0.458, EpiMap: 0.497, TFs:0.435]
# 09/02 09:16:36 AM | VALIDATION: Batch: 1/1, Loss: 0.689, perc_uncertainty: 0.891, custom[HumanFC:0.555, EpiMap:0.598, TFs:0.482], roc[HumanFC: 0.458, EpiMap: 0.497, TFs:0.435]
# 09/02 09:16:36 AM | VALIDATION: Batch: 1/1, Loss: 0.689, perc_uncertainty: 0.891, custom[HumanFC:0.555, EpiMap:0.598, TFs:0.482], roc[HumanFC: 0.458, EpiMap: 0.497, TFs:0.435]
# 09/02 09:16:37 AM | percentage of uncertainty in validation prediction: 0.8882507150629148
# 09/02 09:16:37 AM | percentage of uncertainty in validation prediction: 0.8882507150629148
# 09/02 09:16:37 AM | percentage of uncertainty in validation prediction: 0.8882507150629148
# 09/02 09:16:37 AM | percentage of uncertainty in validation prediction: 0.8882507150629148
# 09/02 09:16:38 AM | TRAINING: Epoch: 8, Batch: 0/32, Loss: 0.685, perc_uncertainty: 0.806, custom[HumanFC:0.531, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.000, EpiMap:0.692, TFs:0.705]
# 09/02 09:16:38 AM | TRAINING: Epoch: 8, Batch: 0/32, Loss: 0.685, perc_uncertainty: 0.806, custom[HumanFC:0.531, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.000, EpiMap:0.692, TFs:0.705]
# 09/02 09:16:38 AM | TRAINING: Epoch: 8, Batch: 0/32, Loss: 0.685, perc_uncertainty: 0.806, custom[HumanFC:0.531, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.000, EpiMap:0.692, TFs:0.705]
# 09/02 09:16:38 AM | TRAINING: Epoch: 8, Batch: 0/32, Loss: 0.685, perc_uncertainty: 0.806, custom[HumanFC:0.531, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.000, EpiMap:0.692, TFs:0.705]
# 09/02 09:17:12 AM | TRAINING: Epoch: 8, Batch: 32/32, Loss: 0.681, perc_uncertainty: 0.807, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.720, TFs:0.000]
# 09/02 09:17:12 AM | TRAINING: Epoch: 8, Batch: 32/32, Loss: 0.681, perc_uncertainty: 0.807, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.720, TFs:0.000]
# 09/02 09:17:12 AM | TRAINING: Epoch: 8, Batch: 32/32, Loss: 0.681, perc_uncertainty: 0.807, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.720, TFs:0.000]
# 09/02 09:17:12 AM | TRAINING: Epoch: 8, Batch: 32/32, Loss: 0.681, perc_uncertainty: 0.807, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.550], roc[HumanFC:0.000, EpiMap:0.720, TFs:0.000]
# 09/02 09:17:15 AM | VALIDATION: Batch: 0/1, Loss: 0.685, perc_uncertainty: 0.000, custom[HumanFC:0.559, EpiMap:0.590, TFs:0.504], roc[HumanFC: 0.509, EpiMap: 0.482, TFs:0.455]
# 09/02 09:17:15 AM | VALIDATION: Batch: 0/1, Loss: 0.685, perc_uncertainty: 0.000, custom[HumanFC:0.559, EpiMap:0.590, TFs:0.504], roc[HumanFC: 0.509, EpiMap: 0.482, TFs:0.455]
# 09/02 09:17:15 AM | VALIDATION: Batch: 0/1, Loss: 0.685, perc_uncertainty: 0.000, custom[HumanFC:0.559, EpiMap:0.590, TFs:0.504], roc[HumanFC: 0.509, EpiMap: 0.482, TFs:0.455]
# 09/02 09:17:15 AM | VALIDATION: Batch: 0/1, Loss: 0.685, perc_uncertainty: 0.000, custom[HumanFC:0.559, EpiMap:0.590, TFs:0.504], roc[HumanFC: 0.509, EpiMap: 0.482, TFs:0.455]
# 09/02 09:17:16 AM | VALIDATION: Batch: 1/1, Loss: 0.684, perc_uncertainty: 0.897, custom[HumanFC:0.567, EpiMap:0.601, TFs:0.500], roc[HumanFC: 0.457, EpiMap: 0.498, TFs:0.435]
# 09/02 09:17:16 AM | VALIDATION: Batch: 1/1, Loss: 0.684, perc_uncertainty: 0.897, custom[HumanFC:0.567, EpiMap:0.601, TFs:0.500], roc[HumanFC: 0.457, EpiMap: 0.498, TFs:0.435]
# 09/02 09:17:16 AM | VALIDATION: Batch: 1/1, Loss: 0.684, perc_uncertainty: 0.897, custom[HumanFC:0.567, EpiMap:0.601, TFs:0.500], roc[HumanFC: 0.457, EpiMap: 0.498, TFs:0.435]
# 09/02 09:17:16 AM | VALIDATION: Batch: 1/1, Loss: 0.684, perc_uncertainty: 0.897, custom[HumanFC:0.567, EpiMap:0.601, TFs:0.500], roc[HumanFC: 0.457, EpiMap: 0.498, TFs:0.435]
# 09/02 09:17:16 AM | percentage of uncertainty in validation prediction: 0.8937976708609843
# 09/02 09:17:16 AM | percentage of uncertainty in validation prediction: 0.8937976708609843
# 09/02 09:17:16 AM | percentage of uncertainty in validation prediction: 0.8937976708609843
# 09/02 09:17:16 AM | percentage of uncertainty in validation prediction: 0.8937976708609843
# 09/02 09:17:18 AM | TRAINING: Epoch: 9, Batch: 0/32, Loss: 0.683, perc_uncertainty: 0.811, custom[HumanFC:0.547, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.794, EpiMap:0.764, TFs:0.622]
# 09/02 09:17:18 AM | TRAINING: Epoch: 9, Batch: 0/32, Loss: 0.683, perc_uncertainty: 0.811, custom[HumanFC:0.547, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.794, EpiMap:0.764, TFs:0.622]
# 09/02 09:17:18 AM | TRAINING: Epoch: 9, Batch: 0/32, Loss: 0.683, perc_uncertainty: 0.811, custom[HumanFC:0.547, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.794, EpiMap:0.764, TFs:0.622]
# 09/02 09:17:18 AM | TRAINING: Epoch: 9, Batch: 0/32, Loss: 0.683, perc_uncertainty: 0.811, custom[HumanFC:0.547, EpiMap:0.578, TFs:0.562], roc[HumanFC:0.794, EpiMap:0.764, TFs:0.622]
# 09/02 09:17:52 AM | TRAINING: Epoch: 9, Batch: 32/32, Loss: 0.667, perc_uncertainty: 0.802, custom[HumanFC:0.600, EpiMap:0.650, TFs:0.550], roc[HumanFC:0.778, EpiMap:0.861, TFs:0.578]
# 09/02 09:17:52 AM | TRAINING: Epoch: 9, Batch: 32/32, Loss: 0.667, perc_uncertainty: 0.802, custom[HumanFC:0.600, EpiMap:0.650, TFs:0.550], roc[HumanFC:0.778, EpiMap:0.861, TFs:0.578]
# 09/02 09:17:52 AM | TRAINING: Epoch: 9, Batch: 32/32, Loss: 0.667, perc_uncertainty: 0.802, custom[HumanFC:0.600, EpiMap:0.650, TFs:0.550], roc[HumanFC:0.778, EpiMap:0.861, TFs:0.578]
# 09/02 09:17:52 AM | TRAINING: Epoch: 9, Batch: 32/32, Loss: 0.667, perc_uncertainty: 0.802, custom[HumanFC:0.600, EpiMap:0.650, TFs:0.550], roc[HumanFC:0.778, EpiMap:0.861, TFs:0.578]
# 09/02 09:17:55 AM | VALIDATION: Batch: 0/1, Loss: 0.681, perc_uncertainty: 0.000, custom[HumanFC:0.582, EpiMap:0.605, TFs:0.516], roc[HumanFC: 0.508, EpiMap: 0.487, TFs:0.444]
# 09/02 09:17:55 AM | VALIDATION: Batch: 0/1, Loss: 0.681, perc_uncertainty: 0.000, custom[HumanFC:0.582, EpiMap:0.605, TFs:0.516], roc[HumanFC: 0.508, EpiMap: 0.487, TFs:0.444]
# 09/02 09:17:55 AM | VALIDATION: Batch: 0/1, Loss: 0.681, perc_uncertainty: 0.000, custom[HumanFC:0.582, EpiMap:0.605, TFs:0.516], roc[HumanFC: 0.508, EpiMap: 0.487, TFs:0.444]
# 09/02 09:17:55 AM | VALIDATION: Batch: 0/1, Loss: 0.681, perc_uncertainty: 0.000, custom[HumanFC:0.582, EpiMap:0.605, TFs:0.516], roc[HumanFC: 0.508, EpiMap: 0.487, TFs:0.444]
# 09/02 09:17:56 AM | VALIDATION: Batch: 1/1, Loss: 0.679, perc_uncertainty: 0.901, custom[HumanFC:0.579, EpiMap:0.628, TFs:0.512], roc[HumanFC: 0.456, EpiMap: 0.502, TFs:0.445]
# 09/02 09:17:56 AM | VALIDATION: Batch: 1/1, Loss: 0.679, perc_uncertainty: 0.901, custom[HumanFC:0.579, EpiMap:0.628, TFs:0.512], roc[HumanFC: 0.456, EpiMap: 0.502, TFs:0.445]
# 09/02 09:17:56 AM | VALIDATION: Batch: 1/1, Loss: 0.679, perc_uncertainty: 0.901, custom[HumanFC:0.579, EpiMap:0.628, TFs:0.512], roc[HumanFC: 0.456, EpiMap: 0.502, TFs:0.445]
# 09/02 09:17:56 AM | VALIDATION: Batch: 1/1, Loss: 0.679, perc_uncertainty: 0.901, custom[HumanFC:0.579, EpiMap:0.628, TFs:0.512], roc[HumanFC: 0.456, EpiMap: 0.502, TFs:0.445]
# 09/02 09:17:56 AM | percentage of uncertainty in validation prediction: 0.8955440033019477
# 09/02 09:17:56 AM | percentage of uncertainty in validation prediction: 0.8955440033019477
# 09/02 09:17:56 AM | percentage of uncertainty in validation prediction: 0.8955440033019477
# 09/02 09:17:56 AM | percentage of uncertainty in validation prediction: 0.8955440033019477
# 09/02 09:17:58 AM | TRAINING: Epoch: 10, Batch: 0/32, Loss: 0.675, perc_uncertainty: 0.814, custom[HumanFC:0.578, EpiMap:0.594, TFs:0.594], roc[HumanFC:0.799, EpiMap:0.786, TFs:0.730]
# 09/02 09:17:58 AM | TRAINING: Epoch: 10, Batch: 0/32, Loss: 0.675, perc_uncertainty: 0.814, custom[HumanFC:0.578, EpiMap:0.594, TFs:0.594], roc[HumanFC:0.799, EpiMap:0.786, TFs:0.730]
# 09/02 09:17:58 AM | TRAINING: Epoch: 10, Batch: 0/32, Loss: 0.675, perc_uncertainty: 0.814, custom[HumanFC:0.578, EpiMap:0.594, TFs:0.594], roc[HumanFC:0.799, EpiMap:0.786, TFs:0.730]
# 09/02 09:17:58 AM | TRAINING: Epoch: 10, Batch: 0/32, Loss: 0.675, perc_uncertainty: 0.814, custom[HumanFC:0.578, EpiMap:0.594, TFs:0.594], roc[HumanFC:0.799, EpiMap:0.786, TFs:0.730]
# 09/02 09:18:32 AM | TRAINING: Epoch: 10, Batch: 32/32, Loss: 0.649, perc_uncertainty: 0.801, custom[HumanFC:0.650, EpiMap:0.700, TFs:0.600], roc[HumanFC:0.917, EpiMap:0.781, TFs:0.769]
# 09/02 09:18:32 AM | TRAINING: Epoch: 10, Batch: 32/32, Loss: 0.649, perc_uncertainty: 0.801, custom[HumanFC:0.650, EpiMap:0.700, TFs:0.600], roc[HumanFC:0.917, EpiMap:0.781, TFs:0.769]
# 09/02 09:18:32 AM | TRAINING: Epoch: 10, Batch: 32/32, Loss: 0.649, perc_uncertainty: 0.801, custom[HumanFC:0.650, EpiMap:0.700, TFs:0.600], roc[HumanFC:0.917, EpiMap:0.781, TFs:0.769]
# 09/02 09:18:32 AM | TRAINING: Epoch: 10, Batch: 32/32, Loss: 0.649, perc_uncertainty: 0.801, custom[HumanFC:0.650, EpiMap:0.700, TFs:0.600], roc[HumanFC:0.917, EpiMap:0.781, TFs:0.769]
# 09/02 09:18:34 AM | VALIDATION: Batch: 0/1, Loss: 0.673, perc_uncertainty: 0.000, custom[HumanFC:0.615, EpiMap:0.646, TFs:0.541], roc[HumanFC: 0.514, EpiMap: 0.488, TFs:0.438]
# 09/02 09:18:34 AM | VALIDATION: Batch: 0/1, Loss: 0.673, perc_uncertainty: 0.000, custom[HumanFC:0.615, EpiMap:0.646, TFs:0.541], roc[HumanFC: 0.514, EpiMap: 0.488, TFs:0.438]
# 09/02 09:18:34 AM | VALIDATION: Batch: 0/1, Loss: 0.673, perc_uncertainty: 0.000, custom[HumanFC:0.615, EpiMap:0.646, TFs:0.541], roc[HumanFC: 0.514, EpiMap: 0.488, TFs:0.438]
# 09/02 09:18:34 AM | VALIDATION: Batch: 0/1, Loss: 0.673, perc_uncertainty: 0.000, custom[HumanFC:0.615, EpiMap:0.646, TFs:0.541], roc[HumanFC: 0.514, EpiMap: 0.488, TFs:0.438]
# 09/02 09:18:36 AM | VALIDATION: Batch: 1/1, Loss: 0.670, perc_uncertainty: 0.905, custom[HumanFC:0.619, EpiMap:0.659, TFs:0.546], roc[HumanFC: 0.457, EpiMap: 0.506, TFs:0.445]
# 09/02 09:18:36 AM | VALIDATION: Batch: 1/1, Loss: 0.670, perc_uncertainty: 0.905, custom[HumanFC:0.619, EpiMap:0.659, TFs:0.546], roc[HumanFC: 0.457, EpiMap: 0.506, TFs:0.445]
# 09/02 09:18:36 AM | VALIDATION: Batch: 1/1, Loss: 0.670, perc_uncertainty: 0.905, custom[HumanFC:0.619, EpiMap:0.659, TFs:0.546], roc[HumanFC: 0.457, EpiMap: 0.506, TFs:0.445]
# 09/02 09:18:36 AM | VALIDATION: Batch: 1/1, Loss: 0.670, perc_uncertainty: 0.905, custom[HumanFC:0.619, EpiMap:0.659, TFs:0.546], roc[HumanFC: 0.457, EpiMap: 0.506, TFs:0.445]
# 09/02 09:18:36 AM | percentage of uncertainty in validation prediction: 0.9001359427518745
# 09/02 09:18:36 AM | percentage of uncertainty in validation prediction: 0.9001359427518745
# 09/02 09:18:36 AM | percentage of uncertainty in validation prediction: 0.9001359427518745
# 09/02 09:18:36 AM | percentage of uncertainty in validation prediction: 0.9001359427518745
# 09/02 09:18:37 AM | TRAINING: Epoch: 11, Batch: 0/32, Loss: 0.674, perc_uncertainty: 0.809, custom[HumanFC:0.578, EpiMap:0.609, TFs:0.578], roc[HumanFC:0.640, EpiMap:0.836, TFs:0.719]
# 09/02 09:18:37 AM | TRAINING: Epoch: 11, Batch: 0/32, Loss: 0.674, perc_uncertainty: 0.809, custom[HumanFC:0.578, EpiMap:0.609, TFs:0.578], roc[HumanFC:0.640, EpiMap:0.836, TFs:0.719]
# 09/02 09:18:37 AM | TRAINING: Epoch: 11, Batch: 0/32, Loss: 0.674, perc_uncertainty: 0.809, custom[HumanFC:0.578, EpiMap:0.609, TFs:0.578], roc[HumanFC:0.640, EpiMap:0.836, TFs:0.719]
# 09/02 09:18:37 AM | TRAINING: Epoch: 11, Batch: 0/32, Loss: 0.674, perc_uncertainty: 0.809, custom[HumanFC:0.578, EpiMap:0.609, TFs:0.578], roc[HumanFC:0.640, EpiMap:0.836, TFs:0.719]
# 09/02 09:19:12 AM | TRAINING: Epoch: 11, Batch: 32/32, Loss: 0.677, perc_uncertainty: 0.796, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.657, TFs:0.529]
# 09/02 09:19:12 AM | TRAINING: Epoch: 11, Batch: 32/32, Loss: 0.677, perc_uncertainty: 0.796, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.657, TFs:0.529]
# 09/02 09:19:12 AM | TRAINING: Epoch: 11, Batch: 32/32, Loss: 0.677, perc_uncertainty: 0.796, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.657, TFs:0.529]
# 09/02 09:19:12 AM | TRAINING: Epoch: 11, Batch: 32/32, Loss: 0.677, perc_uncertainty: 0.796, custom[HumanFC:0.550, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.657, TFs:0.529]
# 09/02 09:19:14 AM | VALIDATION: Batch: 0/1, Loss: 0.669, perc_uncertainty: 0.000, custom[HumanFC:0.639, EpiMap:0.656, TFs:0.559], roc[HumanFC: 0.501, EpiMap: 0.488, TFs:0.444]
# 09/02 09:19:14 AM | VALIDATION: Batch: 0/1, Loss: 0.669, perc_uncertainty: 0.000, custom[HumanFC:0.639, EpiMap:0.656, TFs:0.559], roc[HumanFC: 0.501, EpiMap: 0.488, TFs:0.444]
# 09/02 09:19:14 AM | VALIDATION: Batch: 0/1, Loss: 0.669, perc_uncertainty: 0.000, custom[HumanFC:0.639, EpiMap:0.656, TFs:0.559], roc[HumanFC: 0.501, EpiMap: 0.488, TFs:0.444]
# 09/02 09:19:14 AM | VALIDATION: Batch: 0/1, Loss: 0.669, perc_uncertainty: 0.000, custom[HumanFC:0.639, EpiMap:0.656, TFs:0.559], roc[HumanFC: 0.501, EpiMap: 0.488, TFs:0.444]
# 09/02 09:19:16 AM | VALIDATION: Batch: 1/1, Loss: 0.666, perc_uncertainty: 0.905, custom[HumanFC:0.649, EpiMap:0.677, TFs:0.570], roc[HumanFC: 0.453, EpiMap: 0.504, TFs:0.448]
# 09/02 09:19:16 AM | VALIDATION: Batch: 1/1, Loss: 0.666, perc_uncertainty: 0.905, custom[HumanFC:0.649, EpiMap:0.677, TFs:0.570], roc[HumanFC: 0.453, EpiMap: 0.504, TFs:0.448]
# 09/02 09:19:16 AM | VALIDATION: Batch: 1/1, Loss: 0.666, perc_uncertainty: 0.905, custom[HumanFC:0.649, EpiMap:0.677, TFs:0.570], roc[HumanFC: 0.453, EpiMap: 0.504, TFs:0.448]
# 09/02 09:19:16 AM | VALIDATION: Batch: 1/1, Loss: 0.666, perc_uncertainty: 0.905, custom[HumanFC:0.649, EpiMap:0.677, TFs:0.570], roc[HumanFC: 0.453, EpiMap: 0.504, TFs:0.448]
# 09/02 09:19:16 AM | percentage of uncertainty in validation prediction: 0.8997600633995518
# 09/02 09:19:16 AM | percentage of uncertainty in validation prediction: 0.8997600633995518
# 09/02 09:19:16 AM | percentage of uncertainty in validation prediction: 0.8997600633995518
# 09/02 09:19:16 AM | percentage of uncertainty in validation prediction: 0.8997600633995518
# 09/02 09:19:17 AM | TRAINING: Epoch: 12, Batch: 0/32, Loss: 0.661, perc_uncertainty: 0.821, custom[HumanFC:0.609, EpiMap:0.656, TFs:0.609], roc[HumanFC:0.947, EpiMap:0.868, TFs:0.761]
# 09/02 09:19:17 AM | TRAINING: Epoch: 12, Batch: 0/32, Loss: 0.661, perc_uncertainty: 0.821, custom[HumanFC:0.609, EpiMap:0.656, TFs:0.609], roc[HumanFC:0.947, EpiMap:0.868, TFs:0.761]
# 09/02 09:19:17 AM | TRAINING: Epoch: 12, Batch: 0/32, Loss: 0.661, perc_uncertainty: 0.821, custom[HumanFC:0.609, EpiMap:0.656, TFs:0.609], roc[HumanFC:0.947, EpiMap:0.868, TFs:0.761]
# 09/02 09:19:17 AM | TRAINING: Epoch: 12, Batch: 0/32, Loss: 0.661, perc_uncertainty: 0.821, custom[HumanFC:0.609, EpiMap:0.656, TFs:0.609], roc[HumanFC:0.947, EpiMap:0.868, TFs:0.761]
# 09/02 09:19:51 AM | TRAINING: Epoch: 12, Batch: 32/32, Loss: 0.630, perc_uncertainty: 0.782, custom[HumanFC:0.700, EpiMap:0.750, TFs:0.650], roc[HumanFC:1.000, EpiMap:0.955, TFs:0.805]
# 09/02 09:19:51 AM | TRAINING: Epoch: 12, Batch: 32/32, Loss: 0.630, perc_uncertainty: 0.782, custom[HumanFC:0.700, EpiMap:0.750, TFs:0.650], roc[HumanFC:1.000, EpiMap:0.955, TFs:0.805]
# 09/02 09:19:51 AM | TRAINING: Epoch: 12, Batch: 32/32, Loss: 0.630, perc_uncertainty: 0.782, custom[HumanFC:0.700, EpiMap:0.750, TFs:0.650], roc[HumanFC:1.000, EpiMap:0.955, TFs:0.805]
# 09/02 09:19:51 AM | TRAINING: Epoch: 12, Batch: 32/32, Loss: 0.630, perc_uncertainty: 0.782, custom[HumanFC:0.700, EpiMap:0.750, TFs:0.650], roc[HumanFC:1.000, EpiMap:0.955, TFs:0.805]
# 09/02 09:19:54 AM | VALIDATION: Batch: 0/1, Loss: 0.662, perc_uncertainty: 0.000, custom[HumanFC:0.672, EpiMap:0.684, TFs:0.572], roc[HumanFC: 0.511, EpiMap: 0.496, TFs:0.444]
# 09/02 09:19:54 AM | VALIDATION: Batch: 0/1, Loss: 0.662, perc_uncertainty: 0.000, custom[HumanFC:0.672, EpiMap:0.684, TFs:0.572], roc[HumanFC: 0.511, EpiMap: 0.496, TFs:0.444]
# 09/02 09:19:54 AM | VALIDATION: Batch: 0/1, Loss: 0.662, perc_uncertainty: 0.000, custom[HumanFC:0.672, EpiMap:0.684, TFs:0.572], roc[HumanFC: 0.511, EpiMap: 0.496, TFs:0.444]
# 09/02 09:19:54 AM | VALIDATION: Batch: 0/1, Loss: 0.662, perc_uncertainty: 0.000, custom[HumanFC:0.672, EpiMap:0.684, TFs:0.572], roc[HumanFC: 0.511, EpiMap: 0.496, TFs:0.444]
# 09/02 09:19:55 AM | VALIDATION: Batch: 1/1, Loss: 0.659, perc_uncertainty: 0.904, custom[HumanFC:0.683, EpiMap:0.692, TFs:0.573], roc[HumanFC: 0.455, EpiMap: 0.502, TFs:0.468]
# 09/02 09:19:55 AM | VALIDATION: Batch: 1/1, Loss: 0.659, perc_uncertainty: 0.904, custom[HumanFC:0.683, EpiMap:0.692, TFs:0.573], roc[HumanFC: 0.455, EpiMap: 0.502, TFs:0.468]
# 09/02 09:19:55 AM | VALIDATION: Batch: 1/1, Loss: 0.659, perc_uncertainty: 0.904, custom[HumanFC:0.683, EpiMap:0.692, TFs:0.573], roc[HumanFC: 0.455, EpiMap: 0.502, TFs:0.468]
# 09/02 09:19:55 AM | VALIDATION: Batch: 1/1, Loss: 0.659, perc_uncertainty: 0.904, custom[HumanFC:0.683, EpiMap:0.692, TFs:0.573], roc[HumanFC: 0.455, EpiMap: 0.502, TFs:0.468]
# 09/02 09:19:55 AM | percentage of uncertainty in validation prediction: 0.8980825776469448
# 09/02 09:19:55 AM | percentage of uncertainty in validation prediction: 0.8980825776469448
# 09/02 09:19:55 AM | percentage of uncertainty in validation prediction: 0.8980825776469448
# 09/02 09:19:55 AM | percentage of uncertainty in validation prediction: 0.8980825776469448
# 09/02 09:19:57 AM | TRAINING: Epoch: 13, Batch: 0/32, Loss: 0.636, perc_uncertainty: 0.786, custom[HumanFC:0.688, EpiMap:0.750, TFs:0.641], roc[HumanFC:0.929, EpiMap:0.923, TFs:0.801]
# 09/02 09:19:57 AM | TRAINING: Epoch: 13, Batch: 0/32, Loss: 0.636, perc_uncertainty: 0.786, custom[HumanFC:0.688, EpiMap:0.750, TFs:0.641], roc[HumanFC:0.929, EpiMap:0.923, TFs:0.801]
# 09/02 09:19:57 AM | TRAINING: Epoch: 13, Batch: 0/32, Loss: 0.636, perc_uncertainty: 0.786, custom[HumanFC:0.688, EpiMap:0.750, TFs:0.641], roc[HumanFC:0.929, EpiMap:0.923, TFs:0.801]
# 09/02 09:19:57 AM | TRAINING: Epoch: 13, Batch: 0/32, Loss: 0.636, perc_uncertainty: 0.786, custom[HumanFC:0.688, EpiMap:0.750, TFs:0.641], roc[HumanFC:0.929, EpiMap:0.923, TFs:0.801]
# 09/02 09:20:31 AM | TRAINING: Epoch: 13, Batch: 32/32, Loss: 0.670, perc_uncertainty: 0.793, custom[HumanFC:0.600, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.000]
# 09/02 09:20:31 AM | TRAINING: Epoch: 13, Batch: 32/32, Loss: 0.670, perc_uncertainty: 0.793, custom[HumanFC:0.600, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.000]
# 09/02 09:20:31 AM | TRAINING: Epoch: 13, Batch: 32/32, Loss: 0.670, perc_uncertainty: 0.793, custom[HumanFC:0.600, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.000]
# 09/02 09:20:31 AM | TRAINING: Epoch: 13, Batch: 32/32, Loss: 0.670, perc_uncertainty: 0.793, custom[HumanFC:0.600, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.000]
# 09/02 09:20:33 AM | VALIDATION: Batch: 0/1, Loss: 0.663, perc_uncertainty: 0.000, custom[HumanFC:0.664, EpiMap:0.678, TFs:0.568], roc[HumanFC: 0.502, EpiMap: 0.491, TFs:0.453]
# 09/02 09:20:33 AM | VALIDATION: Batch: 0/1, Loss: 0.663, perc_uncertainty: 0.000, custom[HumanFC:0.664, EpiMap:0.678, TFs:0.568], roc[HumanFC: 0.502, EpiMap: 0.491, TFs:0.453]
# 09/02 09:20:33 AM | VALIDATION: Batch: 0/1, Loss: 0.663, perc_uncertainty: 0.000, custom[HumanFC:0.664, EpiMap:0.678, TFs:0.568], roc[HumanFC: 0.502, EpiMap: 0.491, TFs:0.453]
# 09/02 09:20:33 AM | VALIDATION: Batch: 0/1, Loss: 0.663, perc_uncertainty: 0.000, custom[HumanFC:0.664, EpiMap:0.678, TFs:0.568], roc[HumanFC: 0.502, EpiMap: 0.491, TFs:0.453]
# 09/02 09:20:35 AM | VALIDATION: Batch: 1/1, Loss: 0.660, perc_uncertainty: 0.906, custom[HumanFC:0.683, EpiMap:0.686, TFs:0.558], roc[HumanFC: 0.452, EpiMap: 0.495, TFs:0.452]
# 09/02 09:20:35 AM | VALIDATION: Batch: 1/1, Loss: 0.660, perc_uncertainty: 0.906, custom[HumanFC:0.683, EpiMap:0.686, TFs:0.558], roc[HumanFC: 0.452, EpiMap: 0.495, TFs:0.452]
# 09/02 09:20:35 AM | VALIDATION: Batch: 1/1, Loss: 0.660, perc_uncertainty: 0.906, custom[HumanFC:0.683, EpiMap:0.686, TFs:0.558], roc[HumanFC: 0.452, EpiMap: 0.495, TFs:0.452]
# 09/02 09:20:35 AM | VALIDATION: Batch: 1/1, Loss: 0.660, perc_uncertainty: 0.906, custom[HumanFC:0.683, EpiMap:0.686, TFs:0.558], roc[HumanFC: 0.452, EpiMap: 0.495, TFs:0.452]
# 09/02 09:20:35 AM | percentage of uncertainty in validation prediction: 0.9016153890696372
# 09/02 09:20:35 AM | percentage of uncertainty in validation prediction: 0.9016153890696372
# 09/02 09:20:35 AM | percentage of uncertainty in validation prediction: 0.9016153890696372
# 09/02 09:20:35 AM | percentage of uncertainty in validation prediction: 0.9016153890696372
# 09/02 09:20:36 AM | TRAINING: Epoch: 14, Batch: 0/32, Loss: 0.638, perc_uncertainty: 0.797, custom[HumanFC:0.672, EpiMap:0.766, TFs:0.656], roc[HumanFC:0.990, EpiMap:0.935, TFs:0.859]
# 09/02 09:20:36 AM | TRAINING: Epoch: 14, Batch: 0/32, Loss: 0.638, perc_uncertainty: 0.797, custom[HumanFC:0.672, EpiMap:0.766, TFs:0.656], roc[HumanFC:0.990, EpiMap:0.935, TFs:0.859]
# 09/02 09:20:36 AM | TRAINING: Epoch: 14, Batch: 0/32, Loss: 0.638, perc_uncertainty: 0.797, custom[HumanFC:0.672, EpiMap:0.766, TFs:0.656], roc[HumanFC:0.990, EpiMap:0.935, TFs:0.859]
# 09/02 09:20:36 AM | TRAINING: Epoch: 14, Batch: 0/32, Loss: 0.638, perc_uncertainty: 0.797, custom[HumanFC:0.672, EpiMap:0.766, TFs:0.656], roc[HumanFC:0.990, EpiMap:0.935, TFs:0.859]
# 09/02 09:21:10 AM | TRAINING: Epoch: 14, Batch: 32/32, Loss: 0.669, perc_uncertainty: 0.784, custom[HumanFC:0.600, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.586]
# 09/02 09:21:10 AM | TRAINING: Epoch: 14, Batch: 32/32, Loss: 0.669, perc_uncertainty: 0.784, custom[HumanFC:0.600, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.586]
# 09/02 09:21:10 AM | TRAINING: Epoch: 14, Batch: 32/32, Loss: 0.669, perc_uncertainty: 0.784, custom[HumanFC:0.600, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.586]
# 09/02 09:21:10 AM | TRAINING: Epoch: 14, Batch: 32/32, Loss: 0.669, perc_uncertainty: 0.784, custom[HumanFC:0.600, EpiMap:0.600, TFs:0.600], roc[HumanFC:0.000, EpiMap:0.000, TFs:0.586]
# 09/02 09:21:13 AM | VALIDATION: Batch: 0/1, Loss: 0.656, perc_uncertainty: 0.000, custom[HumanFC:0.695, EpiMap:0.707, TFs:0.604], roc[HumanFC: 0.499, EpiMap: 0.487, TFs:0.449]
# 09/02 09:21:13 AM | VALIDATION: Batch: 0/1, Loss: 0.656, perc_uncertainty: 0.000, custom[HumanFC:0.695, EpiMap:0.707, TFs:0.604], roc[HumanFC: 0.499, EpiMap: 0.487, TFs:0.449]
# 09/02 09:21:13 AM | VALIDATION: Batch: 0/1, Loss: 0.656, perc_uncertainty: 0.000, custom[HumanFC:0.695, EpiMap:0.707, TFs:0.604], roc[HumanFC: 0.499, EpiMap: 0.487, TFs:0.449]
# 09/02 09:21:13 AM | VALIDATION: Batch: 0/1, Loss: 0.656, perc_uncertainty: 0.000, custom[HumanFC:0.695, EpiMap:0.707, TFs:0.604], roc[HumanFC: 0.499, EpiMap: 0.487, TFs:0.449]
# 09/02 09:21:14 AM | VALIDATION: Batch: 1/1, Loss: 0.653, perc_uncertainty: 0.897, custom[HumanFC:0.707, EpiMap:0.707, TFs:0.588], roc[HumanFC: 0.437, EpiMap: 0.491, TFs:0.450]
# 09/02 09:21:14 AM | VALIDATION: Batch: 1/1, Loss: 0.653, perc_uncertainty: 0.897, custom[HumanFC:0.707, EpiMap:0.707, TFs:0.588], roc[HumanFC: 0.437, EpiMap: 0.491, TFs:0.450]
# 09/02 09:21:14 AM | VALIDATION: Batch: 1/1, Loss: 0.653, perc_uncertainty: 0.897, custom[HumanFC:0.707, EpiMap:0.707, TFs:0.588], roc[HumanFC: 0.437, EpiMap: 0.491, TFs:0.450]
# 09/02 09:21:14 AM | VALIDATION: Batch: 1/1, Loss: 0.653, perc_uncertainty: 0.897, custom[HumanFC:0.707, EpiMap:0.707, TFs:0.588], roc[HumanFC: 0.437, EpiMap: 0.491, TFs:0.450]
# 09/02 09:21:14 AM | percentage of uncertainty in validation prediction: 0.892480409834741
# 09/02 09:21:14 AM | percentage of uncertainty in validation prediction: 0.892480409834741
# 09/02 09:21:14 AM | percentage of uncertainty in validation prediction: 0.892480409834741
# 09/02 09:21:14 AM | percentage of uncertainty in validation prediction: 0.892480409834741
# 09/02 09:21:16 AM | TRAINING: Epoch: 15, Batch: 0/32, Loss: 0.646, perc_uncertainty: 0.812, custom[HumanFC:0.641, EpiMap:0.703, TFs:0.672], roc[HumanFC:1.000, EpiMap:0.935, TFs:0.849]
# 09/02 09:21:16 AM | TRAINING: Epoch: 15, Batch: 0/32, Loss: 0.646, perc_uncertainty: 0.812, custom[HumanFC:0.641, EpiMap:0.703, TFs:0.672], roc[HumanFC:1.000, EpiMap:0.935, TFs:0.849]
# 09/02 09:21:16 AM | TRAINING: Epoch: 15, Batch: 0/32, Loss: 0.646, perc_uncertainty: 0.812, custom[HumanFC:0.641, EpiMap:0.703, TFs:0.672], roc[HumanFC:1.000, EpiMap:0.935, TFs:0.849]
# 09/02 09:21:16 AM | TRAINING: Epoch: 15, Batch: 0/32, Loss: 0.646, perc_uncertainty: 0.812, custom[HumanFC:0.641, EpiMap:0.703, TFs:0.672], roc[HumanFC:1.000, EpiMap:0.935, TFs:0.849]
# 09/02 09:21:50 AM | TRAINING: Epoch: 15, Batch: 32/32, Loss: 0.623, perc_uncertainty: 0.771, custom[HumanFC:0.700, EpiMap:0.800, TFs:0.700], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.863]
# 09/02 09:21:50 AM | TRAINING: Epoch: 15, Batch: 32/32, Loss: 0.623, perc_uncertainty: 0.771, custom[HumanFC:0.700, EpiMap:0.800, TFs:0.700], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.863]
# 09/02 09:21:50 AM | TRAINING: Epoch: 15, Batch: 32/32, Loss: 0.623, perc_uncertainty: 0.771, custom[HumanFC:0.700, EpiMap:0.800, TFs:0.700], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.863]
# 09/02 09:21:50 AM | TRAINING: Epoch: 15, Batch: 32/32, Loss: 0.623, perc_uncertainty: 0.771, custom[HumanFC:0.700, EpiMap:0.800, TFs:0.700], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.863]
# 09/02 09:21:52 AM | VALIDATION: Batch: 0/1, Loss: 0.649, perc_uncertainty: 0.000, custom[HumanFC:0.727, EpiMap:0.727, TFs:0.633], roc[HumanFC: 0.504, EpiMap: 0.499, TFs:0.451]
# 09/02 09:21:52 AM | VALIDATION: Batch: 0/1, Loss: 0.649, perc_uncertainty: 0.000, custom[HumanFC:0.727, EpiMap:0.727, TFs:0.633], roc[HumanFC: 0.504, EpiMap: 0.499, TFs:0.451]
# 09/02 09:21:52 AM | VALIDATION: Batch: 0/1, Loss: 0.649, perc_uncertainty: 0.000, custom[HumanFC:0.727, EpiMap:0.727, TFs:0.633], roc[HumanFC: 0.504, EpiMap: 0.499, TFs:0.451]
# 09/02 09:21:52 AM | VALIDATION: Batch: 0/1, Loss: 0.649, perc_uncertainty: 0.000, custom[HumanFC:0.727, EpiMap:0.727, TFs:0.633], roc[HumanFC: 0.504, EpiMap: 0.499, TFs:0.451]
# 09/02 09:21:54 AM | VALIDATION: Batch: 1/1, Loss: 0.646, perc_uncertainty: 0.896, custom[HumanFC:0.744, EpiMap:0.726, TFs:0.607], roc[HumanFC: 0.439, EpiMap: 0.494, TFs:0.441]
# 09/02 09:21:54 AM | VALIDATION: Batch: 1/1, Loss: 0.646, perc_uncertainty: 0.896, custom[HumanFC:0.744, EpiMap:0.726, TFs:0.607], roc[HumanFC: 0.439, EpiMap: 0.494, TFs:0.441]
# ...
# 09/02 10:14:54 AM | TRAINING: Epoch: 96, Batch: 0/32, Loss: 0.412, perc_uncertainty: 0.135, custom[HumanFC:0.984, EpiMap:0.969, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.994, TFs:0.958]
# 09/02 10:14:54 AM | TRAINING: Epoch: 96, Batch: 0/32, Loss: 0.412, perc_uncertainty: 0.135, custom[HumanFC:0.984, EpiMap:0.969, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.994, TFs:0.958]
# 09/02 10:15:29 AM | TRAINING: Epoch: 96, Batch: 32/32, Loss: 0.339, perc_uncertainty: 0.057, custom[HumanFC:0.950, EpiMap:0.950, TFs:0.900], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.941]
# 09/02 10:15:29 AM | TRAINING: Epoch: 96, Batch: 32/32, Loss: 0.339, perc_uncertainty: 0.057, custom[HumanFC:0.950, EpiMap:0.950, TFs:0.900], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.941]
# 09/02 10:15:29 AM | TRAINING: Epoch: 96, Batch: 32/32, Loss: 0.339, perc_uncertainty: 0.057, custom[HumanFC:0.950, EpiMap:0.950, TFs:0.900], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.941]
# 09/02 10:15:29 AM | TRAINING: Epoch: 96, Batch: 32/32, Loss: 0.339, perc_uncertainty: 0.057, custom[HumanFC:0.950, EpiMap:0.950, TFs:0.900], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.941]
# 09/02 10:15:31 AM | VALIDATION: Batch: 0/1, Loss: 0.466, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.965], roc[HumanFC: 0.479, EpiMap: 0.511, TFs:0.460]
# 09/02 10:15:31 AM | VALIDATION: Batch: 0/1, Loss: 0.466, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.965], roc[HumanFC: 0.479, EpiMap: 0.511, TFs:0.460]
# 09/02 10:15:31 AM | VALIDATION: Batch: 0/1, Loss: 0.466, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.965], roc[HumanFC: 0.479, EpiMap: 0.511, TFs:0.460]
# 09/02 10:15:31 AM | VALIDATION: Batch: 0/1, Loss: 0.466, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.965], roc[HumanFC: 0.479, EpiMap: 0.511, TFs:0.460]
# 09/02 10:15:33 AM | VALIDATION: Batch: 1/1, Loss: 0.456, perc_uncertainty: 0.111, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.432, EpiMap: 0.491, TFs:0.457]
# 09/02 10:15:33 AM | VALIDATION: Batch: 1/1, Loss: 0.456, perc_uncertainty: 0.111, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.432, EpiMap: 0.491, TFs:0.457]
# 09/02 10:15:33 AM | VALIDATION: Batch: 1/1, Loss: 0.456, perc_uncertainty: 0.111, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.432, EpiMap: 0.491, TFs:0.457]
# 09/02 10:15:33 AM | VALIDATION: Batch: 1/1, Loss: 0.456, perc_uncertainty: 0.111, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.432, EpiMap: 0.491, TFs:0.457]
# 09/02 10:15:33 AM | percentage of uncertainty in validation prediction: 0.11090890084999569
# 09/02 10:15:33 AM | percentage of uncertainty in validation prediction: 0.11090890084999569
# 09/02 10:15:33 AM | percentage of uncertainty in validation prediction: 0.11090890084999569
# 09/02 10:15:33 AM | percentage of uncertainty in validation prediction: 0.11090890084999569
# 09/02 10:15:34 AM | TRAINING: Epoch: 97, Batch: 0/32, Loss: 0.406, perc_uncertainty: 0.132, custom[HumanFC:0.984, EpiMap:0.984, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.998, TFs:0.972]
# 09/02 10:15:34 AM | TRAINING: Epoch: 97, Batch: 0/32, Loss: 0.406, perc_uncertainty: 0.132, custom[HumanFC:0.984, EpiMap:0.984, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.998, TFs:0.972]
# 09/02 10:15:34 AM | TRAINING: Epoch: 97, Batch: 0/32, Loss: 0.406, perc_uncertainty: 0.132, custom[HumanFC:0.984, EpiMap:0.984, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.998, TFs:0.972]
# 09/02 10:15:34 AM | TRAINING: Epoch: 97, Batch: 0/32, Loss: 0.406, perc_uncertainty: 0.132, custom[HumanFC:0.984, EpiMap:0.984, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.998, TFs:0.972]
# 09/02 10:16:09 AM | TRAINING: Epoch: 97, Batch: 32/32, Loss: 0.375, perc_uncertainty: 0.077, custom[HumanFC:1.000, EpiMap:1.000, TFs:0.950], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.947]
# 09/02 10:16:09 AM | TRAINING: Epoch: 97, Batch: 32/32, Loss: 0.375, perc_uncertainty: 0.077, custom[HumanFC:1.000, EpiMap:1.000, TFs:0.950], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.947]
# 09/02 10:16:09 AM | TRAINING: Epoch: 97, Batch: 32/32, Loss: 0.375, perc_uncertainty: 0.077, custom[HumanFC:1.000, EpiMap:1.000, TFs:0.950], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.947]
# 09/02 10:16:09 AM | TRAINING: Epoch: 97, Batch: 32/32, Loss: 0.375, perc_uncertainty: 0.077, custom[HumanFC:1.000, EpiMap:1.000, TFs:0.950], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.947]
# 09/02 10:16:11 AM | VALIDATION: Batch: 0/1, Loss: 0.474, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.965], roc[HumanFC: 0.478, EpiMap: 0.514, TFs:0.461]
# 09/02 10:16:11 AM | VALIDATION: Batch: 0/1, Loss: 0.474, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.965], roc[HumanFC: 0.478, EpiMap: 0.514, TFs:0.461]
# 09/02 10:16:11 AM | VALIDATION: Batch: 0/1, Loss: 0.474, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.965], roc[HumanFC: 0.478, EpiMap: 0.514, TFs:0.461]
# 09/02 10:16:11 AM | VALIDATION: Batch: 0/1, Loss: 0.474, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.965], roc[HumanFC: 0.478, EpiMap: 0.514, TFs:0.461]
# 09/02 10:16:13 AM | VALIDATION: Batch: 1/1, Loss: 0.465, perc_uncertainty: 0.133, custom[HumanFC:0.957, EpiMap:0.881, TFs:0.915], roc[HumanFC: 0.438, EpiMap: 0.495, TFs:0.457]
# 09/02 10:16:13 AM | VALIDATION: Batch: 1/1, Loss: 0.465, perc_uncertainty: 0.133, custom[HumanFC:0.957, EpiMap:0.881, TFs:0.915], roc[HumanFC: 0.438, EpiMap: 0.495, TFs:0.457]
# 09/02 10:16:13 AM | VALIDATION: Batch: 1/1, Loss: 0.465, perc_uncertainty: 0.133, custom[HumanFC:0.957, EpiMap:0.881, TFs:0.915], roc[HumanFC: 0.438, EpiMap: 0.495, TFs:0.457]
# 09/02 10:16:13 AM | VALIDATION: Batch: 1/1, Loss: 0.465, perc_uncertainty: 0.133, custom[HumanFC:0.957, EpiMap:0.881, TFs:0.915], roc[HumanFC: 0.438, EpiMap: 0.495, TFs:0.457]
# 09/02 10:16:13 AM | percentage of uncertainty in validation prediction: 0.13228807003038007
# 09/02 10:16:13 AM | percentage of uncertainty in validation prediction: 0.13228807003038007
# 09/02 10:16:13 AM | percentage of uncertainty in validation prediction: 0.13228807003038007
# 09/02 10:16:13 AM | percentage of uncertainty in validation prediction: 0.13228807003038007
# 09/02 10:16:14 AM | TRAINING: Epoch: 98, Batch: 0/32, Loss: 0.419, perc_uncertainty: 0.139, custom[HumanFC:0.969, EpiMap:0.938, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.984, TFs:0.963]
# 09/02 10:16:14 AM | TRAINING: Epoch: 98, Batch: 0/32, Loss: 0.419, perc_uncertainty: 0.139, custom[HumanFC:0.969, EpiMap:0.938, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.984, TFs:0.963]
# 09/02 10:16:14 AM | TRAINING: Epoch: 98, Batch: 0/32, Loss: 0.419, perc_uncertainty: 0.139, custom[HumanFC:0.969, EpiMap:0.938, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.984, TFs:0.963]
# 09/02 10:16:14 AM | TRAINING: Epoch: 98, Batch: 0/32, Loss: 0.419, perc_uncertainty: 0.139, custom[HumanFC:0.969, EpiMap:0.938, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.984, TFs:0.963]
# 09/02 10:16:48 AM | TRAINING: Epoch: 98, Batch: 32/32, Loss: 0.398, perc_uncertainty: 0.100, custom[HumanFC:0.950, EpiMap:0.950, TFs:0.950], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.869]
# 09/02 10:16:48 AM | TRAINING: Epoch: 98, Batch: 32/32, Loss: 0.398, perc_uncertainty: 0.100, custom[HumanFC:0.950, EpiMap:0.950, TFs:0.950], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.869]
# 09/02 10:16:48 AM | TRAINING: Epoch: 98, Batch: 32/32, Loss: 0.398, perc_uncertainty: 0.100, custom[HumanFC:0.950, EpiMap:0.950, TFs:0.950], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.869]
# 09/02 10:16:48 AM | TRAINING: Epoch: 98, Batch: 32/32, Loss: 0.398, perc_uncertainty: 0.100, custom[HumanFC:0.950, EpiMap:0.950, TFs:0.950], roc[HumanFC:1.000, EpiMap:1.000, TFs:0.869]
# 09/02 10:16:51 AM | VALIDATION: Batch: 0/1, Loss: 0.472, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.477, EpiMap: 0.513, TFs:0.459]
# 09/02 10:16:51 AM | VALIDATION: Batch: 0/1, Loss: 0.472, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.477, EpiMap: 0.513, TFs:0.459]
# 09/02 10:16:51 AM | VALIDATION: Batch: 0/1, Loss: 0.472, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.477, EpiMap: 0.513, TFs:0.459]
# 09/02 10:16:51 AM | VALIDATION: Batch: 0/1, Loss: 0.472, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.477, EpiMap: 0.513, TFs:0.459]
# 09/02 10:16:52 AM | VALIDATION: Batch: 1/1, Loss: 0.463, perc_uncertainty: 0.132, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.434, EpiMap: 0.490, TFs:0.459]
# 09/02 10:16:52 AM | VALIDATION: Batch: 1/1, Loss: 0.463, perc_uncertainty: 0.132, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.434, EpiMap: 0.490, TFs:0.459]
# 09/02 10:16:52 AM | VALIDATION: Batch: 1/1, Loss: 0.463, perc_uncertainty: 0.132, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.434, EpiMap: 0.490, TFs:0.459]
# 09/02 10:16:52 AM | VALIDATION: Batch: 1/1, Loss: 0.463, perc_uncertainty: 0.132, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.434, EpiMap: 0.490, TFs:0.459]
# 09/02 10:16:53 AM | percentage of uncertainty in validation prediction: 0.1322549933206929
# 09/02 10:16:53 AM | percentage of uncertainty in validation prediction: 0.1322549933206929
# 09/02 10:16:53 AM | percentage of uncertainty in validation prediction: 0.1322549933206929
# 09/02 10:16:53 AM | percentage of uncertainty in validation prediction: 0.1322549933206929
# 09/02 10:16:54 AM | TRAINING: Epoch: 99, Batch: 0/32, Loss: 0.404, perc_uncertainty: 0.124, custom[HumanFC:0.953, EpiMap:0.953, TFs:0.930], roc[HumanFC:0.997, EpiMap:0.992, TFs:0.948]
# 09/02 10:16:54 AM | TRAINING: Epoch: 99, Batch: 0/32, Loss: 0.404, perc_uncertainty: 0.124, custom[HumanFC:0.953, EpiMap:0.953, TFs:0.930], roc[HumanFC:0.997, EpiMap:0.992, TFs:0.948]
# 09/02 10:16:54 AM | TRAINING: Epoch: 99, Batch: 0/32, Loss: 0.404, perc_uncertainty: 0.124, custom[HumanFC:0.953, EpiMap:0.953, TFs:0.930], roc[HumanFC:0.997, EpiMap:0.992, TFs:0.948]
# 09/02 10:16:54 AM | TRAINING: Epoch: 99, Batch: 0/32, Loss: 0.404, perc_uncertainty: 0.124, custom[HumanFC:0.953, EpiMap:0.953, TFs:0.930], roc[HumanFC:0.997, EpiMap:0.992, TFs:0.948]
# 09/02 10:17:29 AM | TRAINING: Epoch: 99, Batch: 32/32, Loss: 0.425, perc_uncertainty: 0.131, custom[HumanFC:1.000, EpiMap:0.950, TFs:0.950], roc[HumanFC:1.000, EpiMap:0.947, TFs:0.000]
# 09/02 10:17:29 AM | TRAINING: Epoch: 99, Batch: 32/32, Loss: 0.425, perc_uncertainty: 0.131, custom[HumanFC:1.000, EpiMap:0.950, TFs:0.950], roc[HumanFC:1.000, EpiMap:0.947, TFs:0.000]
# 09/02 10:17:29 AM | TRAINING: Epoch: 99, Batch: 32/32, Loss: 0.425, perc_uncertainty: 0.131, custom[HumanFC:1.000, EpiMap:0.950, TFs:0.950], roc[HumanFC:1.000, EpiMap:0.947, TFs:0.000]
# 09/02 10:17:29 AM | TRAINING: Epoch: 99, Batch: 32/32, Loss: 0.425, perc_uncertainty: 0.131, custom[HumanFC:1.000, EpiMap:0.950, TFs:0.950], roc[HumanFC:1.000, EpiMap:0.947, TFs:0.000]
# 09/02 10:17:31 AM | VALIDATION: Batch: 0/1, Loss: 0.475, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.477, EpiMap: 0.513, TFs:0.460]
# 09/02 10:17:31 AM | VALIDATION: Batch: 0/1, Loss: 0.475, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.477, EpiMap: 0.513, TFs:0.460]
# 09/02 10:17:31 AM | VALIDATION: Batch: 0/1, Loss: 0.475, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.477, EpiMap: 0.513, TFs:0.460]
# 09/02 10:17:31 AM | VALIDATION: Batch: 0/1, Loss: 0.475, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.477, EpiMap: 0.513, TFs:0.460]
# 09/02 10:17:32 AM | VALIDATION: Batch: 1/1, Loss: 0.466, perc_uncertainty: 0.140, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.437, EpiMap: 0.493, TFs:0.457]
# 09/02 10:17:32 AM | VALIDATION: Batch: 1/1, Loss: 0.466, perc_uncertainty: 0.140, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.437, EpiMap: 0.493, TFs:0.457]
# 09/02 10:17:32 AM | VALIDATION: Batch: 1/1, Loss: 0.466, perc_uncertainty: 0.140, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.437, EpiMap: 0.493, TFs:0.457]
# 09/02 10:17:32 AM | VALIDATION: Batch: 1/1, Loss: 0.466, perc_uncertainty: 0.140, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.437, EpiMap: 0.493, TFs:0.457]
# 09/02 10:17:33 AM | percentage of uncertainty in validation prediction: 0.13951562567331727
# 09/02 10:17:33 AM | percentage of uncertainty in validation prediction: 0.13951562567331727
# 09/02 10:17:33 AM | percentage of uncertainty in validation prediction: 0.13951562567331727
# 09/02 10:17:33 AM | percentage of uncertainty in validation prediction: 0.13951562567331727
# 09/02 10:17:34 AM | TRAINING: Epoch: 100, Batch: 0/32, Loss: 0.421, perc_uncertainty: 0.143, custom[HumanFC:0.984, EpiMap:0.969, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.997, TFs:0.921]
# 09/02 10:17:34 AM | TRAINING: Epoch: 100, Batch: 0/32, Loss: 0.421, perc_uncertainty: 0.143, custom[HumanFC:0.984, EpiMap:0.969, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.997, TFs:0.921]
# 09/02 10:17:34 AM | TRAINING: Epoch: 100, Batch: 0/32, Loss: 0.421, perc_uncertainty: 0.143, custom[HumanFC:0.984, EpiMap:0.969, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.997, TFs:0.921]
# 09/02 10:17:34 AM | TRAINING: Epoch: 100, Batch: 0/32, Loss: 0.421, perc_uncertainty: 0.143, custom[HumanFC:0.984, EpiMap:0.969, TFs:0.953], roc[HumanFC:1.000, EpiMap:0.997, TFs:0.921]
# 09/02 10:18:08 AM | TRAINING: Epoch: 100, Batch: 32/32, Loss: 0.446, perc_uncertainty: 0.226, custom[HumanFC:0.900, EpiMap:0.950, TFs:0.950], roc[HumanFC:0.000, EpiMap:1.000, TFs:0.000]
# 09/02 10:18:08 AM | TRAINING: Epoch: 100, Batch: 32/32, Loss: 0.446, perc_uncertainty: 0.226, custom[HumanFC:0.900, EpiMap:0.950, TFs:0.950], roc[HumanFC:0.000, EpiMap:1.000, TFs:0.000]
# 09/02 10:18:08 AM | TRAINING: Epoch: 100, Batch: 32/32, Loss: 0.446, perc_uncertainty: 0.226, custom[HumanFC:0.900, EpiMap:0.950, TFs:0.950], roc[HumanFC:0.000, EpiMap:1.000, TFs:0.000]
# 09/02 10:18:08 AM | TRAINING: Epoch: 100, Batch: 32/32, Loss: 0.446, perc_uncertainty: 0.226, custom[HumanFC:0.900, EpiMap:0.950, TFs:0.950], roc[HumanFC:0.000, EpiMap:1.000, TFs:0.000]
# 09/02 10:18:11 AM | VALIDATION: Batch: 0/1, Loss: 0.476, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.479, EpiMap: 0.513, TFs:0.459]
# 09/02 10:18:11 AM | VALIDATION: Batch: 0/1, Loss: 0.476, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.479, EpiMap: 0.513, TFs:0.459]
# 09/02 10:18:11 AM | VALIDATION: Batch: 0/1, Loss: 0.476, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.479, EpiMap: 0.513, TFs:0.459]
# 09/02 10:18:11 AM | VALIDATION: Batch: 0/1, Loss: 0.476, perc_uncertainty: 0.000, custom[HumanFC:0.918, EpiMap:0.863, TFs:0.961], roc[HumanFC: 0.479, EpiMap: 0.513, TFs:0.459]
# 09/02 10:18:12 AM | VALIDATION: Batch: 1/1, Loss: 0.466, perc_uncertainty: 0.139, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.441, EpiMap: 0.497, TFs:0.461]
# 09/02 10:18:12 AM | VALIDATION: Batch: 1/1, Loss: 0.466, perc_uncertainty: 0.139, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.441, EpiMap: 0.497, TFs:0.461]
# 09/02 10:18:12 AM | VALIDATION: Batch: 1/1, Loss: 0.466, perc_uncertainty: 0.139, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.441, EpiMap: 0.497, TFs:0.461]
# 09/02 10:18:12 AM | VALIDATION: Batch: 1/1, Loss: 0.466, perc_uncertainty: 0.139, custom[HumanFC:0.957, EpiMap:0.884, TFs:0.915], roc[HumanFC: 0.441, EpiMap: 0.497, TFs:0.461]
# 09/02 10:18:12 AM | percentage of uncertainty in validation prediction: 0.13830626373567179
# 09/02 10:18:12 AM | percentage of uncertainty in validation prediction: 0.13830626373567179
# 09/02 10:18:12 AM | percentage of uncertainty in validation prediction: 0.13830626373567179
# 09/02 10:18:12 AM | percentage of uncertainty in validation prediction: 0.13830626373567179
